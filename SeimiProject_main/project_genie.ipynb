# %% [markdown]
# 패키지 설치

# %%
import pandas as pd
from pandas import DataFrame
import requests
from bs4 import BeautifulSoup
import datetime as dt

# %% [markdown]
# 날짜 구하기

# %%
# 오늘 날짜 구하기
today = dt.date.today()
# 오늘 날짜 숫자 형식으로 출력
today_number = today.strftime("%Y%m%d")
# 이번 달 1일 날짜 구하기
start_month = dt.date(today.year, today.month, 1)
# 이번 달 1일 날짜 숫자 형식으로 출력
# start_month_number = start_month.strftime("%Y%m%d")
# 어제 날짜 구하기
yesterday = today - dt.timedelta(days=1)
# 이번 달 1일 부터 어제 날짜까지 구하기
delta = yesterday - start_month
length = (delta.days + 1)
# 날짜 추출
days=int(today_number)

# %% [markdown]
# 웹 페이지 데이터 수집 코드

# %%
# 수집할 음원 사이트의 주소 페이지 설정
# 1~50, 51~100으로 2개의 페이지로 나눠져 있음
pages = ['1', '2']
# dict 형식의 제목, 가수, 앨범, 순위 등 정보를 담을 빈 list 생성
genie_chart = []

# 날짜별 데이터 수집(이번 달 1일 부터 어제 날짜까지)

for i in range(length):
    # 날짜 계산
    date = (start_month + dt.timedelta(days=i)).strftime("%Y%m%d")
    modified_date = (start_month + dt.timedelta(days=i)).strftime("%Y%m%d")[0:6] + "{:02d}".format(i + 1)
    
    for p in pages:
        # 갱신된 날짜로 URL 생성
        # 수집할 컨텐츠가 있는 날짜별 웹 페이지 주소
        url = f'https://www.genie.co.kr/chart/top200?ditc=D&ymd={date}&hh=09&rtm=N&pg={p}'
        # print(url)

        # 브라우저 버전정보
        userAgent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36'

        # 접속 객체 생성
        # request는 직접 header 정보 갱신이 불가능해 session 생성
        session = requests.Session()

        # 접속 객체에 부가정보(header) 삽입, 크롤링이 가능하도록 유도
        session.headers.update({
            "Referer": "",
            "User-Agent": userAgent
        })

        # 생성한 접속 객체를 활용해 웹 페이지에 접속
        # 지정된 URL에 GET 요청을 보내고
        # 그에 대한 응답을 r 변수에 할당
        r = session.get(url)

        # 접속 실패 시 에러 코드와 에러 메시지 출력
        if r.status_code != 200:
            msg = "[%d Error] %s 에러 발생" % (r.status_code, r.reason)
            raise Exception(msg)

        # 인코딩 형식을 지정해 beautifulsoup 객체를 생성
        r.encoding = 'utf-8'

        # r 변수에 저장된 text 정보를 시각화, 확인
        # print(r.text)

        # r.text에서 HTML을 파싱하고,
        # 파싱된 HTML을 나타내는
        # BeautifulSoup 객체 soup를 생성
        soup = BeautifulSoup(r.text)
        # print(soup)



        # 추출할 음원의 수를 확인하기 위해 재생 버튼을 나타내는
        # .btn-basic.btn-listen의 수를 확인해 반복할 횟수를 정한다
        # 재생 버튼은 음원에만 존재하기 때문에 .btn-basic.btn-listen 사용
        
        genie_list = soup.select(".btn-basic.btn-listen")

        # 반복문의 길이로 사용하기 적합한지 확인
        # print(len(genie_list))
        

        # .number도 사용 가능함
        # genie_list = soup.select(".number")
        # print(len(genie_list))
        

        for j in range(len(genie_list)):

            # 제목 추출
            # 제목의 class는 title ellipsis였음
            songEl = soup.select('.title.ellipsis')
            song = songEl[j].text.strip()
            # print(song)
            

            # 가수 추출
            # 가수의 class는 artist ellipsis
            singerEl = soup.select('.artist.ellipsis')
            singer = singerEl[j].text.strip()
            # print(singer)
            

            # 앨범 추출
            # 앨범의 class는 albumtitle ellipsis
            albumEl = soup.select('.albumtitle.ellipsis')
            album = albumEl[j].text.strip()
            # print(album)


            # 순위 설정
            # 각 페이지 별로 순위가 다르게 입력되도록 유도
            # 1페이지는 1~50, 2페이지는 51~100으로 유도
            rank = (int(p)-1) * 50 + (j+1)

            # 날짜 추출용(안 하면 하루씩 밀림)
            if rank==1:
                days-=1

            # 추출한 데이터를 dict 형태로 변환
            item = {"날짜" : modified_date, "곡명": song, "아티스트": singer, "앨범명": album, "순위" : rank}

            # dict 정보를 genie_chart에 삽입
            genie_chart.append(item)
            
genie_chart
# Out:
# [{'날짜': '20230601',
#   '곡명': '퀸카 (Queencard)',
#   '아티스트': '(여자)아이들',
#   '앨범명': 'I feel',
#   '순위': 1},
#  {'날짜': '20230601',
#   '곡명': 'I AM',
#   '아티스트': 'IVE (아이브)',
#   '앨범명': "I've IVE",
#   '순위': 2},
#  {'날짜': '20230601',
#   '곡명': 'Spicy',
#   '아티스트': 'aespa',
#   '앨범명': 'MY WORLD - The 3rd Mini Album',
#   '순위': 3},
#  {'날짜': '20230601',
#   '곡명': 'Kitsch',
#   '아티스트': 'IVE (아이브)',
#   '앨범명': "I've IVE",
#   '순위': 4},
#  {'날짜': '20230601',
#   '곡명': 'UNFORGIVEN (Feat. Nile Rodgers)',
#   '아티스트': 'LE SSERAFIM (르세라핌)',
#   '앨범명': 'UNFORGIVEN',
#   '순위': 5},
#  {'날짜': '20230601', '곡명': '꽃', '아티스트': '지수 (JISOO)', '앨범명': 'ME', '순위': 6},
#  {'날짜': '20230601',
#   '곡명': 'Hype boy',
#   '아티스트': 'NewJeans',
#   '앨범명': "NewJeans 1st EP 'New Jeans'",
#   '순위': 7},
#  {'날짜': '20230601',
#   '곡명': 'Ditto',
#   '아티스트': 'NewJeans',
#   '앨범명': "NewJeans 'OMG'",
#   '순위': 8},
#  {'날짜': '20230601',
#   '곡명': '사건의 지평선',
#   '아티스트': '윤하 (YOUNHA)',
#   '앨범명': "YOUNHA 6th Album Repackage 'END THEORY : Final Edition'",
#   '순위': 9},
#  {'날짜': '20230601',
#   '곡명': '손오공',
#   '아티스트': '세븐틴 (SEVENTEEN)',
#   '앨범명': "SEVENTEEN 10th Mini Album 'FML'",
#   '순위': 10},
#  {'날짜': '20230601',
#   '곡명': 'Cupid',
#   '아티스트': 'FIFTY FIFTY',
#   '앨범명': 'The Beginning : Cupid',
#   '순위': 11},
#  {'날짜': '20230601',
#   '곡명': "I Don't Think That I Like Her",
#   '아티스트': 'Charlie Puth',
#   '앨범명': 'CHARLIE',
#   '순위': 12},
#  {'날짜': '20230601',
#   '곡명': 'Teddy Bear',
#   '아티스트': 'STAYC (스테이씨)',
#   '앨범명': 'Teddy Bear',
#   '순위': 13},
#  {'날짜': '20230601',
#   '곡명': '심 (心)',
#   '아티스트': 'DK (디셈버)',
#   '앨범명': '심 (心)',
#   '순위': 14},
#  {'날짜': '20230601',
#   '곡명': 'After LIKE',
#   '아티스트': 'IVE (아이브)',
#   '앨범명': 'After LIKE',
#   '순위': 15},
#  {'날짜': '20230601',
#   '곡명': 'OMG',
#   '아티스트': 'NewJeans',
#   '앨범명': "NewJeans 'OMG'",
#   '순위': 16},
#  {'날짜': '20230601',
#   '곡명': 'Dangerously',
#   '아티스트': 'Charlie Puth',
#   '앨범명': 'Nine Track Mind (Deluxe Edition)',
#   '순위': 17},
#  {'날짜': '20230601',
#   '곡명': '파이팅 해야지 (Feat. 이영지)',
#   '아티스트': '부석순 (SEVENTEEN)',
#   '앨범명': "부석순 1st Single Album 'SECOND WIND'",
#   '순위': 18},
#  {'날짜': '20230601',
#   '곡명': 'LOVE DIVE',
#   '아티스트': 'IVE (아이브)',
#   '앨범명': 'LOVE DIVE',
#   '순위': 19},
#  {'날짜': '20230601',
#   '곡명': 'Attention',
#   '아티스트': 'NewJeans',
#   '앨범명': "NewJeans 1st EP 'New Jeans'",
#   '순위': 20},
#  {'날짜': '20230601',
#   '곡명': 'CHRISTIAN',
#   '아티스트': 'Zior Park',
#   '앨범명': 'WHERE DOES SASQUATCH LIVE? PART 1',
#   '순위': 21},
#  {'날짜': '20230601',
#   '곡명': '헤어지자 말해요',
#   '아티스트': '박재정',
#   '앨범명': '1집 Alone',
#   '순위': 22},
#  {'날짜': '20230601',
#   '곡명': 'ANTIFRAGILE',
#   '아티스트': 'LE SSERAFIM (르세라핌)',
#   '앨범명': 'ANTIFRAGILE',
#   '순위': 23},
#  {'날짜': '20230601',
#   '곡명': '이브, 프시케 그리고 푸른 수염의 아내',
#   '아티스트': 'LE SSERAFIM (르세라핌)',
#   '앨범명': 'UNFORGIVEN',
#   '순위': 24},
#  {'날짜': '20230601',
#   '곡명': '사랑인가 봐',
#   '아티스트': '멜로망스 (MeloMance)',
#   '앨범명': '사랑인가 봐 (사내맞선 OST 스페셜 트랙)',
#   '순위': 25},
#  {'날짜': '20230601',
#   '곡명': '건물 사이에 피어난 장미',
#   '아티스트': 'H1-KEY (하이키)',
#   '앨범명': 'H1-KEY 1st Mini Album (Rose Blossom)',
#   '순위': 26},
#  {'날짜': '20230601',
#   '곡명': 'NIGHT DANCER',
#   '아티스트': 'imase',
#   '앨범명': 'NIGHT DANCER',
#   '순위': 27},
#  {'날짜': '20230601', '곡명': '물론', '아티스트': '허각', '앨범명': '물론', '순위': 28},
#  {'날짜': '20230601',
#   '곡명': '사랑은 늘 도망가',
#   '아티스트': '임영웅',
#   '앨범명': '신사와 아가씨 OST Part.2',
#   '순위': 29},
#  {'날짜': '20230601',
#   '곡명': 'TOMBOY',
#   '아티스트': '(여자)아이들',
#   '앨범명': 'I NEVER DIE',
#   '순위': 30},
#  {'날짜': '20230601',
#   '곡명': "That's Hilarious",
#   '아티스트': 'Charlie Puth',
#   '앨범명': 'CHARLIE',
#   '순위': 31},
#  {'날짜': '20230601',
#   '곡명': '취중고백',
#   '아티스트': '김민석 (멜로망스)',
#   '앨범명': '취중고백',
#   '순위': 32},
#  {'날짜': '20230601',
#   '곡명': '다정히 내 이름을 부르면',
#   '아티스트': '경서예지 & 전건호',
#   '앨범명': '다정히 내 이름을 부르면',
#   '순위': 33},
#  {'날짜': '20230601',
#   '곡명': 'Nxde',
#   '아티스트': '(여자)아이들',
#   '앨범명': 'I love',
#   '순위': 34},
#  {'날짜': '20230601',
#   '곡명': 'The Drum',
#   '아티스트': 'Alan Walker',
#   '앨범명': 'Walkerverse, Pt. I',
#   '순위': 35},
#  {'날짜': '20230601',
#   '곡명': '빛이 나는 너에게',
#   '아티스트': '던 (DAWN)',
#   '앨범명': '빛이 나는 너에게',
#   '순위': 36},
#  {'날짜': '20230601',
#   '곡명': 'Heaven (2023)',
#   '아티스트': '임재현',
#   '앨범명': '시작은 첫키스 OST Part.1',
#   '순위': 37},
#  {'날짜': '20230601',
#   '곡명': 'Shut Down',
#   '아티스트': 'BLACKPINK',
#   '앨범명': 'BORN PINK',
#   '순위': 38},
#  {'날짜': '20230601',
#   '곡명': '그때 그 순간 그대로 (그그그)',
#   '아티스트': 'WSG워너비 (가야G)',
#   '앨범명': 'WSG워너비 1집',
#   '순위': 39},
#  {'날짜': '20230601',
#   '곡명': 'KNOCK',
#   '아티스트': '이채연',
#   '앨범명': 'Over The Moon',
#   '순위': 40},
#  {'날짜': '20230601', '곡명': '그라데이션', '아티스트': '10CM', '앨범명': '5.3', '순위': 41},
#  {'날짜': '20230601',
#   '곡명': '사랑..그게 뭔데',
#   '아티스트': '지아 (Zia)',
#   '앨범명': '사랑..그게 뭔데',
#   '순위': 42},
#  {'날짜': '20230601',
#   '곡명': '너의 모든 순간',
#   '아티스트': '성시경',
#   '앨범명': '별에서 온 그대 OST Part.7 (SBS 수목드라마)',
#   '순위': 43},
#  {'날짜': '20230601',
#   '곡명': 'Stay',
#   '아티스트': 'The Kid LAROI & Justin Bieber',
#   '앨범명': 'Stay',
#   '순위': 44},
#  {'날짜': '20230601',
#   '곡명': 'Monologue',
#   '아티스트': '테이 (Tei)',
#   '앨범명': 'Monologue',
#   '순위': 45},
#  {'날짜': '20230601',
#   '곡명': '새삥 (Prod. by ZICO) (Feat. 호미들)',
#   '아티스트': '지코 (ZICO)',
#   '앨범명': '스트릿 맨 파이터(SMF) Original Vol.3 (계급미션)',
#   '순위': 46},
#  {'날짜': '20230601',
#   '곡명': 'Pink Venom',
#   '아티스트': 'BLACKPINK',
#   '앨범명': 'BORN PINK',
#   '순위': 47},
#  {'날짜': '20230601', '곡명': '나의 X에게', '아티스트': '경서', '앨범명': '나의 X에게', '순위': 48},
#  {'날짜': '20230601',
#   '곡명': '찬란한 하루',
#   '아티스트': '멜로망스 (MeloMance)',
#   '앨범명': '찬란한 하루',
#   '순위': 49},
#  {'날짜': '20230601',
#   '곡명': '해요 (2022)',
#   '아티스트': '#안녕',
#   '앨범명': '해요 (2022)',
#   '순위': 50},
#  {'날짜': '20230601',
#   '곡명': 'Allergy',
#   '아티스트': '(여자)아이들',
#   '앨범명': 'I feel',
#   '순위': 51},
#  {'날짜': '20230601',
#   '곡명': '오르트구름',
#   '아티스트': '윤하 (YOUNHA)',
#   '앨범명': "YOUNHA 6th Album 'END THEORY'",
#   '순위': 52},
#  {'날짜': '20230601',
#   '곡명': 'ELEVEN',
#   '아티스트': 'IVE (아이브)',
#   '앨범명': 'ELEVEN',
#   '순위': 53},
#  {'날짜': '20230601',
#   '곡명': '사랑하기 싫어',
#   '아티스트': '지아 (Zia)',
#   '앨범명': '사랑하기 싫어',
#   '순위': 54},
#  {'날짜': '20230601',
#   '곡명': '나의 바람 (Wind And Wish)',
#   '아티스트': '비투비',
#   '앨범명': 'WIND AND WISH',
#   '순위': 55},
#  {'날짜': '20230601',
#   '곡명': 'When I Get Old',
#   '아티스트': 'Christopher & 청하',
#   '앨범명': 'When I Get Old',
#   '순위': 56},
#  {'날짜': '20230601', '곡명': '내가 아니라도', '아티스트': '주호', '앨범명': '내가 아니라도', '순위': 57},
#  {'날짜': '20230601',
#   '곡명': '우리들의 블루스',
#   '아티스트': '임영웅',
#   '앨범명': 'IM HERO',
#   '순위': 58},
#  {'날짜': '20230601',
#   '곡명': 'Loving You Girl (Feat. Hkeem)',
#   '아티스트': 'Peder Elias',
#   '앨범명': 'Love & Loneliness',
#   '순위': 59},
#  {'날짜': '20230601',
#   '곡명': 'FEARLESS',
#   '아티스트': 'LE SSERAFIM (르세라핌)',
#   '앨범명': 'FEARLESS',
#   '순위': 60},
#  {'날짜': '20230601',
#   '곡명': '주저하는 연인들을 위해',
#   '아티스트': '잔나비',
#   '앨범명': '전설',
#   '순위': 61},
#  {'날짜': '20230601',
#   '곡명': 'Dynamite',
#   '아티스트': '방탄소년단',
#   '앨범명': 'Dynamite (DayTime Ver.)',
#   '순위': 62},
#  {'날짜': '20230601',
#   '곡명': '보고싶었어',
#   '아티스트': 'WSG워너비 (4FIRE)',
#   '앨범명': 'WSG워너비 1집',
#   '순위': 63},
#  {'날짜': '20230601',
#   '곡명': '2002',
#   '아티스트': 'Anne-Marie',
#   '앨범명': 'Speak Your Mind (Deluxe)',
#   '순위': 64},
#  {'날짜': '20230601', '곡명': '신호등', '아티스트': '이무진', '앨범명': '신호등', '순위': 65},
#  {'날짜': '20230601',
#   '곡명': '정이라고 하자 (Feat. 10CM)',
#   '아티스트': 'BIG Naughty (서동현)',
#   '앨범명': '정이라고 하자',
#   '순위': 66},
#  {'날짜': '20230601',
#   '곡명': 'Thirsty',
#   '아티스트': 'aespa',
#   '앨범명': 'MY WORLD - The 3rd Mini Album',
#   '순위': 67},
#  {'날짜': '20230601',
#   '곡명': 'Cookie',
#   '아티스트': 'NewJeans',
#   '앨범명': "NewJeans 1st EP 'New Jeans'",
#   '순위': 68},
#  {'날짜': '20230601',
#   '곡명': '잠깐 시간 될까',
#   '아티스트': '이무진',
#   '앨범명': '잠깐 시간 될까',
#   '순위': 69},
#  {'날짜': '20230601',
#   '곡명': 'VIBE (Feat. Jimin of BTS)',
#   '아티스트': '태양',
#   '앨범명': 'VIBE',
#   '순위': 70},
#  {'날짜': '20230601',
#   '곡명': '모든 날, 모든 순간 (Every day, Every Moment)',
#   '아티스트': '폴킴',
#   '앨범명': "'키스 먼저 할까요?' OST Part. 3 (SBS 월화드라마)",
#   '순위': 71},
#  {'날짜': '20230601',
#   '곡명': '이제 나만 믿어요',
#   '아티스트': '임영웅',
#   '앨범명': '내일은 미스터트롯 우승자 특전곡',
#   '순위': 72},
#  {'날짜': '20230601',
#   '곡명': 'Unholy',
#   '아티스트': 'Sam Smith & Kim Petras',
#   '앨범명': 'Unholy',
#   '순위': 73},
#  {'날짜': '20230601',
#   '곡명': 'Say I Love You',
#   '아티스트': '우디 (Woody)',
#   '앨범명': 'Say I Love You (Re : WIND 4MEN Vol.04)',
#   '순위': 74},
#  {'날짜': '20230601',
#   '곡명': 'Off My Face',
#   '아티스트': 'Justin Bieber',
#   '앨범명': 'Justice',
#   '순위': 75},
#  {'날짜': '20230601', '곡명': '희재', '아티스트': '성시경', '앨범명': '국화꽃 향기 OST', '순위': 76},
#  {'날짜': '20230601',
#   '곡명': '밤하늘의 별을 (2020)',
#   '아티스트': '경서',
#   '앨범명': '밤하늘의 별을 (2020)',
#   '순위': 77},
#  {'날짜': '20230601',
#   '곡명': '봄여름가을겨울 (Still Life)',
#   '아티스트': 'BIGBANG (빅뱅)',
#   '앨범명': '봄여름가을겨울 (Still Life)',
#   '순위': 78},
#  {'날짜': '20230601',
#   '곡명': 'Every Second',
#   '아티스트': 'Mina Okabe',
#   '앨범명': 'Every Second',
#   '순위': 79},
#  {'날짜': '20230601',
#   '곡명': 'NOT SORRY (Feat. pH-1) (Prod. by Slom)',
#   '아티스트': '이영지',
#   '앨범명': '쇼미더머니 11 Episode 3',
#   '순위': 80},
#  {'날짜': '20230601',
#   '곡명': '첫 키스에 내 심장은 120BPM',
#   '아티스트': '경서',
#   '앨범명': 'ONGOING',
#   '순위': 81},
#  {'날짜': '20230601',
#   '곡명': '흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야',
#   '아티스트': '장범준',
#   '앨범명': '멜로가 체질 OST Part 3 (JTBC 금토 드라마)',
#   '순위': 82},
#  {'날짜': '20230601',
#   '곡명': 'Dreamers (Music from the FIFA World Cup Qatar 2022 Official Soundtrack) (Feat. FIFA Sound)',
#   '아티스트': '정국 & 방탄소년단',
#   '앨범명': 'Dreamers (Music from the FIFA World Cup Qatar 2022 Official Soundtrack)',
#   '순위': 83},
#  {'날짜': '20230601',
#   '곡명': 'INVU',
#   '아티스트': '태연 (TAEYEON)',
#   '앨범명': 'INVU - The 3rd Album',
#   '순위': 84},
#  {'날짜': '20230601',
#   '곡명': '다시 만날 수 있을까',
#   '아티스트': '임영웅',
#   '앨범명': 'IM HERO',
#   '순위': 85},
#  {'날짜': '20230601',
#   '곡명': 'LOVE me',
#   '아티스트': "BE'O (비오)",
#   '앨범명': 'LOVE me',
#   '순위': 86},
#  {'날짜': '20230601',
#   '곡명': 'Love Me Like This',
#   '아티스트': 'NMIXX',
#   '앨범명': 'expérgo',
#   '순위': 87},
#  {'날짜': '20230601',
#   '곡명': '딱 10CM만',
#   '아티스트': '10CM & BIG Naughty (서동현)',
#   '앨범명': '딱 10CM만',
#   '순위': 88},
#  {'날짜': '20230601',
#   '곡명': 'Bad Habits',
#   '아티스트': 'Ed Sheeran',
#   '앨범명': '=',
#   '순위': 89},
#  {'날짜': '20230601',
#   '곡명': '한사람만 (2023) (여름날 우리 X 이홍기 (FT아일랜드))',
#   '아티스트': '이홍기 (FT아일랜드)',
#   '앨범명': '한사람만 (2023) (여름날 우리 X 이홍기 (FT아일랜드))',
#   '순위': 90},
#  {'날짜': '20230601',
#   '곡명': 'Ai Wo Tsutaetaidatoka',
#   '아티스트': 'aimyon',
#   '앨범명': 'Ai Wo Tsutaetaidatoka',
#   '순위': 91},
#  {'날짜': '20230601',
#   '곡명': 'Candy',
#   '아티스트': 'NCT DREAM',
#   '앨범명': 'Candy - Winter Special Mini Album',
#   '순위': 92},
#  {'날짜': '20230601',
#   '곡명': 'London Boy',
#   '아티스트': '임영웅',
#   '앨범명': 'Polaroid',
#   '순위': 93},
#  {'날짜': '20230601',
#   '곡명': 'Butter',
#   '아티스트': '방탄소년단',
#   '앨범명': 'Butter',
#   '순위': 94},
#  {'날짜': '20230601',
#   '곡명': 'That That (Prod. & Feat. SUGA of BTS)',
#   '아티스트': '싸이 (Psy)',
#   '앨범명': '싸다9',
#   '순위': 95},
#  {'날짜': '20230601',
#   '곡명': 'Rush Hour (Feat. j-hope of BTS)',
#   '아티스트': 'Crush',
#   '앨범명': 'Rush Hour',
#   '순위': 96},
#  {'날짜': '20230601',
#   '곡명': 'Next Level',
#   '아티스트': 'aespa',
#   '앨범명': 'Next Level',
#   '순위': 97},
#  {'날짜': '20230601',
#   '곡명': 'Weekend',
#   '아티스트': '태연 (TAEYEON)',
#   '앨범명': 'Weekend',
#   '순위': 98},
#  {'날짜': '20230601',
#   '곡명': '고백',
#   '아티스트': '멜로망스 (MeloMance)',
#   '앨범명': "세 번째 '고백'",
#   '순위': 99},
#  {'날짜': '20230601',
#   '곡명': '밤이 무서워요 (Lonely Night)',
#   '아티스트': '주주 시크릿',
#   '앨범명': '밤이 무서워요 (Lonely Night)',
#   '순위': 100},
#  {'날짜': '20230602',
#   '곡명': '퀸카 (Queencard)',
#   '아티스트': '(여자)아이들',
#   '앨범명': 'I feel',
#   '순위': 1},
#  {'날짜': '20230602',
#   '곡명': 'I AM',
#   '아티스트': 'IVE (아이브)',
#   '앨범명': "I've IVE",
#   '순위': 2},
#  {'날짜': '20230602',
#   '곡명': 'Spicy',
#   '아티스트': 'aespa',
#   '앨범명': 'MY WORLD - The 3rd Mini Album',
#   '순위': 3},
#  {'날짜': '20230602',
#   '곡명': 'Kitsch',
#   '아티스트': 'IVE (아이브)',
#   '앨범명': "I've IVE",
#   '순위': 4},
#  {'날짜': '20230602',
#   '곡명': 'UNFORGIVEN (Feat. Nile Rodgers)',
#   '아티스트': 'LE SSERAFIM (르세라핌)',
#   '앨범명': 'UNFORGIVEN',
#   '순위': 5},
#  {'날짜': '20230602', '곡명': '꽃', '아티스트': '지수 (JISOO)', '앨범명': 'ME', '순위': 6},
#  {'날짜': '20230602',
#   '곡명': 'Hype boy',
#   '아티스트': 'NewJeans',
#   '앨범명': "NewJeans 1st EP 'New Jeans'",
#   '순위': 7},
#  {'날짜': '20230602',
#   '곡명': 'Ditto',
#   '아티스트': 'NewJeans',
#   '앨범명': "NewJeans 'OMG'",
#   '순위': 8},
#  {'날짜': '20230602',
#   '곡명': '사건의 지평선',
#   '아티스트': '윤하 (YOUNHA)',
#   '앨범명': "YOUNHA 6th Album Repackage 'END THEORY : Final Edition'",
#   '순위': 9},
#  {'날짜': '20230602',
#   '곡명': '손오공',
#   '아티스트': '세븐틴 (SEVENTEEN)',
#   '앨범명': "SEVENTEEN 10th Mini Album 'FML'",
#   '순위': 10},
#  {'날짜': '20230602',
#   '곡명': 'Cupid',
#   '아티스트': 'FIFTY FIFTY',
#   '앨범명': 'The Beginning : Cupid',
#   '순위': 11},
#  {'날짜': '20230602',
#   '곡명': "I Don't Think That I Like Her",
#   '아티스트': 'Charlie Puth',
#   '앨범명': 'CHARLIE',
#   '순위': 12},
#  {'날짜': '20230602',
#   '곡명': 'Teddy Bear',
#   '아티스트': 'STAYC (스테이씨)',
#   '앨범명': 'Teddy Bear',
#   '순위': 13},
#  {'날짜': '20230602',
#   '곡명': '심 (心)',
#   '아티스트': 'DK (디셈버)',
#   '앨범명': '심 (心)',
#   '순위': 14},
#  {'날짜': '20230602',
#   '곡명': 'After LIKE',
#   '아티스트': 'IVE (아이브)',
#   '앨범명': 'After LIKE',
#   '순위': 15},
#  {'날짜': '20230602',
#   '곡명': 'OMG',
#   '아티스트': 'NewJeans',
#   '앨범명': "NewJeans 'OMG'",
#   '순위': 16},
#  {'날짜': '20230602',
#   '곡명': 'Dangerously',
#   '아티스트': 'Charlie Puth',
#   '앨범명': 'Nine Track Mind (Deluxe Edition)',
#   '순위': 17},
#  {'날짜': '20230602',
#   '곡명': '파이팅 해야지 (Feat. 이영지)',
#   '아티스트': '부석순 (SEVENTEEN)',
#   '앨범명': "부석순 1st Single Album 'SECOND WIND'",
#   '순위': 18},
#  {'날짜': '20230602',
#   '곡명': 'LOVE DIVE',
#   '아티스트': 'IVE (아이브)',
#   '앨범명': 'LOVE DIVE',
#   '순위': 19},
#  {'날짜': '20230602',
#   '곡명': 'CHRISTIAN',
#   '아티스트': 'Zior Park',
#   '앨범명': 'WHERE DOES SASQUATCH LIVE? PART 1',
#   '순위': 20},
#  {'날짜': '20230602',
#   '곡명': 'Attention',
#   '아티스트': 'NewJeans',
#   '앨범명': "NewJeans 1st EP 'New Jeans'",
#   '순위': 21},
#  {'날짜': '20230602',
#   '곡명': 'ANTIFRAGILE',
#   '아티스트': 'LE SSERAFIM (르세라핌)',
#   '앨범명': 'ANTIFRAGILE',
#   '순위': 22},
#  {'날짜': '20230602',
#   '곡명': '이브, 프시케 그리고 푸른 수염의 아내',
#   '아티스트': 'LE SSERAFIM (르세라핌)',
#   '앨범명': 'UNFORGIVEN',
#   '순위': 23},
#  {'날짜': '20230602',
#   '곡명': '헤어지자 말해요',
#   '아티스트': '박재정',
#   '앨범명': '1집 Alone',
#   '순위': 24},
#  {'날짜': '20230602',
#   '곡명': '사랑인가 봐',
#   '아티스트': '멜로망스 (MeloMance)',
#   '앨범명': '사랑인가 봐 (사내맞선 OST 스페셜 트랙)',
#   '순위': 25},
#  {'날짜': '20230602',
#   '곡명': '건물 사이에 피어난 장미',
#   '아티스트': 'H1-KEY (하이키)',
#   '앨범명': 'H1-KEY 1st Mini Album (Rose Blossom)',
#   '순위': 26},
#  {'날짜': '20230602',
#   '곡명': 'NIGHT DANCER',
#   '아티스트': 'imase',
#   '앨범명': 'NIGHT DANCER',
#   '순위': 27},
#  {'날짜': '20230602', '곡명': '물론', '아티스트': '허각', '앨범명': '물론', '순위': 28},
#  {'날짜': '20230602',
#   '곡명': '사랑은 늘 도망가',
#   '아티스트': '임영웅',
#   '앨범명': '신사와 아가씨 OST Part.2',
#   '순위': 29},
#  {'날짜': '20230602',
#   '곡명': 'TOMBOY',
#   '아티스트': '(여자)아이들',
#   '앨범명': 'I NEVER DIE',
#   '순위': 30},
#  {'날짜': '20230602',
#   '곡명': "That's Hilarious",
#   '아티스트': 'Charlie Puth',
#   '앨범명': 'CHARLIE',
#   '순위': 31},
#  {'날짜': '20230602',
#   '곡명': 'The Drum',
#   '아티스트': 'Alan Walker',
#   '앨범명': 'Walkerverse, Pt. I',
#   '순위': 32},
#  {'날짜': '20230602',
#   '곡명': 'Nxde',
#   '아티스트': '(여자)아이들',
#   '앨범명': 'I love',
#   '순위': 33},
#  {'날짜': '20230602',
#   '곡명': '취중고백',
#   '아티스트': '김민석 (멜로망스)',
#   '앨범명': '취중고백',
#   '순위': 34},
#  {'날짜': '20230602',
#   '곡명': '다정히 내 이름을 부르면',
#   '아티스트': '경서예지 & 전건호',
#   '앨범명': '다정히 내 이름을 부르면',
#   '순위': 35},
#  {'날짜': '20230602',
#   '곡명': 'Heaven (2023)',
#   '아티스트': '임재현',
#   '앨범명': '시작은 첫키스 OST Part.1',
#   '순위': 36},
#  {'날짜': '20230602',
#   '곡명': 'Shut Down',
#   '아티스트': 'BLACKPINK',
#   '앨범명': 'BORN PINK',
#   '순위': 37},
#  {'날짜': '20230602',
#   '곡명': '빛이 나는 너에게',
#   '아티스트': '던 (DAWN)',
#   '앨범명': '빛이 나는 너에게',
#   '순위': 38},
#  {'날짜': '20230602',
#   '곡명': '그때 그 순간 그대로 (그그그)',
#   '아티스트': 'WSG워너비 (가야G)',
#   '앨범명': 'WSG워너비 1집',
#   '순위': 39},
#  {'날짜': '20230602',
#   '곡명': '새삥 (Prod. by ZICO) (Feat. 호미들)',
#   '아티스트': '지코 (ZICO)',
#   '앨범명': '스트릿 맨 파이터(SMF) Original Vol.3 (계급미션)',
#   '순위': 40},
#  {'날짜': '20230602',
#   '곡명': '너의 모든 순간',
#   '아티스트': '성시경',
#   '앨범명': '별에서 온 그대 OST Part.7 (SBS 수목드라마)',
#   '순위': 41},
#  {'날짜': '20230602',
#   '곡명': 'KNOCK',
#   '아티스트': '이채연',
#   '앨범명': 'Over The Moon',
#   '순위': 42},
#  {'날짜': '20230602',
#   '곡명': 'Stay',
#   '아티스트': 'The Kid LAROI & Justin Bieber',
#   '앨범명': 'Stay',
#   '순위': 43},
#  {'날짜': '20230602', '곡명': '그라데이션', '아티스트': '10CM', '앨범명': '5.3', '순위': 44},
#  {'날짜': '20230602',
#   '곡명': 'Monologue',
#   '아티스트': '테이 (Tei)',
#   '앨범명': 'Monologue',
#   '순위': 45},
#  {'날짜': '20230602', '곡명': '나의 X에게', '아티스트': '경서', '앨범명': '나의 X에게', '순위': 46},
#  {'날짜': '20230602',
#   '곡명': 'Pink Venom',
#   '아티스트': 'BLACKPINK',
#   '앨범명': 'BORN PINK',
#   '순위': 47},
#  {'날짜': '20230602',
#   '곡명': '사랑..그게 뭔데',
#   '아티스트': '지아 (Zia)',
#   '앨범명': '사랑..그게 뭔데',
#   '순위': 48},
#  {'날짜': '20230602',
#   '곡명': 'ELEVEN',
#   '아티스트': 'IVE (아이브)',
#   '앨범명': 'ELEVEN',
#   '순위': 49},
#  {'날짜': '20230602',
#   '곡명': '해요 (2022)',
#   '아티스트': '#안녕',
#   '앨범명': '해요 (2022)',
#   '순위': 50},
#  {'날짜': '20230602',
#   '곡명': 'When I Get Old',
#   '아티스트': 'Christopher & 청하',
#   '앨범명': 'When I Get Old',
#   '순위': 51},
#  {'날짜': '20230602',
#   '곡명': '오르트구름',
#   '아티스트': '윤하 (YOUNHA)',
#   '앨범명': "YOUNHA 6th Album 'END THEORY'",
#   '순위': 52},
#  {'날짜': '20230602',
#   '곡명': 'Allergy',
#   '아티스트': '(여자)아이들',
#   '앨범명': 'I feel',
#   '순위': 53},
#  {'날짜': '20230602',
#   '곡명': '사랑하기 싫어',
#   '아티스트': '지아 (Zia)',
#   '앨범명': '사랑하기 싫어',
#   '순위': 54},
#  {'날짜': '20230602',
#   '곡명': '우리들의 블루스',
#   '아티스트': '임영웅',
#   '앨범명': 'IM HERO',
#   '순위': 55},
#  {'날짜': '20230602', '곡명': '내가 아니라도', '아티스트': '주호', '앨범명': '내가 아니라도', '순위': 56},
#  {'날짜': '20230602',
#   '곡명': 'Loving You Girl (Feat. Hkeem)',
#   '아티스트': 'Peder Elias',
#   '앨범명': 'Love & Loneliness',
#   '순위': 57},
#  {'날짜': '20230602',
#   '곡명': '나의 바람 (Wind And Wish)',
#   '아티스트': '비투비',
#   '앨범명': 'WIND AND WISH',
#   '순위': 58},
#  {'날짜': '20230602',
#   '곡명': 'FEARLESS',
#   '아티스트': 'LE SSERAFIM (르세라핌)',
#   '앨범명': 'FEARLESS',
#   '순위': 59},
#  {'날짜': '20230602',
#   '곡명': '찬란한 하루',
#   '아티스트': '멜로망스 (MeloMance)',
#   '앨범명': '찬란한 하루',
#   '순위': 60},
#  {'날짜': '20230602', '곡명': '신호등', '아티스트': '이무진', '앨범명': '신호등', '순위': 61},
#  {'날짜': '20230602',
#   '곡명': 'Dynamite',
#   '아티스트': '방탄소년단',
#   '앨범명': 'Dynamite (DayTime Ver.)',
#   '순위': 62},
#  {'날짜': '20230602',
#   '곡명': '주저하는 연인들을 위해',
#   '아티스트': '잔나비',
#   '앨범명': '전설',
#   '순위': 63},
#  {'날짜': '20230602',
#   '곡명': '2002',
#   '아티스트': 'Anne-Marie',
#   '앨범명': 'Speak Your Mind (Deluxe)',
#   '순위': 64},
#  {'날짜': '20230602',
#   '곡명': '보고싶었어',
#   '아티스트': 'WSG워너비 (4FIRE)',
#   '앨범명': 'WSG워너비 1집',
#   '순위': 65},
#  {'날짜': '20230602',
#   '곡명': '정이라고 하자 (Feat. 10CM)',
#   '아티스트': 'BIG Naughty (서동현)',
#   '앨범명': '정이라고 하자',
#   '순위': 66},
#  {'날짜': '20230602',
#   '곡명': 'Cookie',
#   '아티스트': 'NewJeans',
#   '앨범명': "NewJeans 1st EP 'New Jeans'",
#   '순위': 67},
#  {'날짜': '20230602',
#   '곡명': 'VIBE (Feat. Jimin of BTS)',
#   '아티스트': '태양',
#   '앨범명': 'VIBE',
#   '순위': 68},
#  {'날짜': '20230602',
#   '곡명': '잠깐 시간 될까',
#   '아티스트': '이무진',
#   '앨범명': '잠깐 시간 될까',
#   '순위': 69},
#  {'날짜': '20230602',
#   '곡명': '이제 나만 믿어요',
#   '아티스트': '임영웅',
#   '앨범명': '내일은 미스터트롯 우승자 특전곡',
#   '순위': 70},
#  {'날짜': '20230602',
#   '곡명': '모든 날, 모든 순간 (Every day, Every Moment)',
#   '아티스트': '폴킴',
#   '앨범명': "'키스 먼저 할까요?' OST Part. 3 (SBS 월화드라마)",
#   '순위': 71},
#  {'날짜': '20230602',
#   '곡명': 'Thirsty',
#   '아티스트': 'aespa',
#   '앨범명': 'MY WORLD - The 3rd Mini Album',
#   '순위': 72},
#  {'날짜': '20230602',
#   '곡명': '밤하늘의 별을 (2020)',
#   '아티스트': '경서',
#   '앨범명': '밤하늘의 별을 (2020)',
#   '순위': 73},
#  {'날짜': '20230602',
#   '곡명': 'Off My Face',
#   '아티스트': 'Justin Bieber',
#   '앨범명': 'Justice',
#   '순위': 74},
#  {'날짜': '20230602',
#   '곡명': 'Unholy',
#   '아티스트': 'Sam Smith & Kim Petras',
#   '앨범명': 'Unholy',
#   '순위': 75},
#  {'날짜': '20230602', '곡명': '희재', '아티스트': '성시경', '앨범명': '국화꽃 향기 OST', '순위': 76},
#  {'날짜': '20230602',
#   '곡명': 'Say I Love You',
#   '아티스트': '우디 (Woody)',
#   '앨범명': 'Say I Love You (Re : WIND 4MEN Vol.04)',
#   '순위': 77},
#  {'날짜': '20230602',
#   '곡명': 'NOT SORRY (Feat. pH-1) (Prod. by Slom)',
#   '아티스트': '이영지',
#   '앨범명': '쇼미더머니 11 Episode 3',
#   '순위': 78},
#  {'날짜': '20230602',
#   '곡명': '봄여름가을겨울 (Still Life)',
#   '아티스트': 'BIGBANG (빅뱅)',
#   '앨범명': '봄여름가을겨울 (Still Life)',
#   '순위': 79},
#  {'날짜': '20230602',
#   '곡명': 'Every Second',
#   '아티스트': 'Mina Okabe',
#   '앨범명': 'Every Second',
#   '순위': 80},
#  {'날짜': '20230602',
#   '곡명': 'Dreamers (Music from the FIFA World Cup Qatar 2022 Official Soundtrack) (Feat. FIFA Sound)',
#   '아티스트': '정국 & 방탄소년단',
#   '앨범명': 'Dreamers (Music from the FIFA World Cup Qatar 2022 Official Soundtrack)',
#   '순위': 81},
#  {'날짜': '20230602',
#   '곡명': '다시 만날 수 있을까',
#   '아티스트': '임영웅',
#   '앨범명': 'IM HERO',
#   '순위': 82},
#  {'날짜': '20230602',
#   '곡명': '흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야',
#   '아티스트': '장범준',
#   '앨범명': '멜로가 체질 OST Part 3 (JTBC 금토 드라마)',
#   '순위': 83},
#  {'날짜': '20230602',
#   '곡명': 'London Boy',
#   '아티스트': '임영웅',
#   '앨범명': 'Polaroid',
#   '순위': 84},
#  {'날짜': '20230602',
#   '곡명': 'INVU',
#   '아티스트': '태연 (TAEYEON)',
#   '앨범명': 'INVU - The 3rd Album',
#   '순위': 85},
#  {'날짜': '20230602',
#   '곡명': 'Bad Habits',
#   '아티스트': 'Ed Sheeran',
#   '앨범명': '=',
#   '순위': 86},
#  {'날짜': '20230602',
#   '곡명': '딱 10CM만',
#   '아티스트': '10CM & BIG Naughty (서동현)',
#   '앨범명': '딱 10CM만',
#   '순위': 87},
#  {'날짜': '20230602',
#   '곡명': 'LOVE me',
#   '아티스트': "BE'O (비오)",
#   '앨범명': 'LOVE me',
#   '순위': 88},
#  {'날짜': '20230602',
#   '곡명': '첫 키스에 내 심장은 120BPM',
#   '아티스트': '경서',
#   '앨범명': 'ONGOING',
#   '순위': 89},
#  {'날짜': '20230602',
#   '곡명': 'Candy',
#   '아티스트': 'NCT DREAM',
#   '앨범명': 'Candy - Winter Special Mini Album',
#   '순위': 90},
#  {'날짜': '20230602',
#   '곡명': 'Ai Wo Tsutaetaidatoka',
#   '아티스트': 'aimyon',
#   '앨범명': 'Ai Wo Tsutaetaidatoka',
#   '순위': 91},
#  {'날짜': '20230602',
#   '곡명': 'Love Me Like This',
#   '아티스트': 'NMIXX',
#   '앨범명': 'expérgo',
#   '순위': 92},
#  {'날짜': '20230602',
#   '곡명': 'Rush Hour (Feat. j-hope of BTS)',
#   '아티스트': 'Crush',
#   '앨범명': 'Rush Hour',
#   '순위': 93},
#  {'날짜': '20230602',
#   '곡명': 'Next Level',
#   '아티스트': 'aespa',
#   '앨범명': 'Next Level',
#   '순위': 94},
#  {'날짜': '20230602',
#   '곡명': 'Butter',
#   '아티스트': '방탄소년단',
#   '앨범명': 'Butter',
#   '순위': 95},
#  {'날짜': '20230602',
#   '곡명': 'That That (Prod. & Feat. SUGA of BTS)',
#   '아티스트': '싸이 (Psy)',
#   '앨범명': '싸다9',
#   '순위': 96},
#  {'날짜': '20230602',
#   '곡명': 'Weekend',
#   '아티스트': '태연 (TAEYEON)',
#   '앨범명': 'Weekend',
#   '순위': 97},
#  {'날짜': '20230602',
#   '곡명': 'Nostalgia',
#   '아티스트': '우디 (Woody)',
#   '앨범명': 'Nostalgia',
#   '순위': 98},
#  {'날짜': '20230602',
#   '곡명': '특',
#   '아티스트': 'Stray Kids (스트레이 키즈)',
#   '앨범명': '★★★★★ (5-STAR)',
#   '순위': 99},
#  {'날짜': '20230602',
#   '곡명': '밤이 무서워요 (Lonely Night)',
#   '아티스트': '주주 시크릿',
#   '앨범명': '밤이 무서워요 (Lonely Night)',
#   '순위': 100},
#  {'날짜': '20230603',
#   '곡명': '퀸카 (Queencard)',
#   '아티스트': '(여자)아이들',
#   '앨범명': 'I feel',
#   '순위': 1},
#  {'날짜': '20230603',
#   '곡명': 'I AM',
#   '아티스트': 'IVE (아이브)',
#   '앨범명': "I've IVE",
#   '순위': 2},
#  {'날짜': '20230603',
#   '곡명': 'Spicy',
#   '아티스트': 'aespa',
#   '앨범명': 'MY WORLD - The 3rd Mini Album',
#   '순위': 3},
#  {'날짜': '20230603',
#   '곡명': 'Kitsch',
#   '아티스트': 'IVE (아이브)',
#   '앨범명': "I've IVE",
#   '순위': 4},
#  {'날짜': '20230603',
#   '곡명': 'UNFORGIVEN (Feat. Nile Rodgers)',
#   '아티스트': 'LE SSERAFIM (르세라핌)',
#   '앨범명': 'UNFORGIVEN',
#   '순위': 5},
#  {'날짜': '20230603', '곡명': '꽃', '아티스트': '지수 (JISOO)', '앨범명': 'ME', '순위': 6},
#  {'날짜': '20230603',
#   '곡명': 'Hype boy',
#   '아티스트': 'NewJeans',
#   '앨범명': "NewJeans 1st EP 'New Jeans'",
#   '순위': 7},
#  {'날짜': '20230603',
#   '곡명': 'Ditto',
#   '아티스트': 'NewJeans',
#   '앨범명': "NewJeans 'OMG'",
#   '순위': 8},
#  {'날짜': '20230603',
#   '곡명': '사건의 지평선',
#   '아티스트': '윤하 (YOUNHA)',
#   '앨범명': "YOUNHA 6th Album Repackage 'END THEORY : Final Edition'",
#   '순위': 9},
#  {'날짜': '20230603',
#   '곡명': 'Cupid',
#   '아티스트': 'FIFTY FIFTY',
#   '앨범명': 'The Beginning : Cupid',
#   '순위': 10},
#  {'날짜': '20230603',
#   '곡명': '손오공',
#   '아티스트': '세븐틴 (SEVENTEEN)',
#   '앨범명': "SEVENTEEN 10th Mini Album 'FML'",
#   '순위': 11},
#  {'날짜': '20230603',
#   '곡명': "I Don't Think That I Like Her",
#   '아티스트': 'Charlie Puth',
#   '앨범명': 'CHARLIE',
#   '순위': 12},
#  {'날짜': '20230603',
#   '곡명': 'After LIKE',
#   '아티스트': 'IVE (아이브)',
#   '앨범명': 'After LIKE',
#   '순위': 13},
#  {'날짜': '20230603',
#   '곡명': 'Teddy Bear',
#   '아티스트': 'STAYC (스테이씨)',
#   '앨범명': 'Teddy Bear',
#   '순위': 14},
#  {'날짜': '20230603',
#   '곡명': '심 (心)',
#   '아티스트': 'DK (디셈버)',
#   '앨범명': '심 (心)',
#   '순위': 15},
#  {'날짜': '20230603',
#   '곡명': 'OMG',
#   '아티스트': 'NewJeans',
#   '앨범명': "NewJeans 'OMG'",
#   '순위': 16},
#  {'날짜': '20230603',
#   '곡명': '파이팅 해야지 (Feat. 이영지)',
#   '아티스트': '부석순 (SEVENTEEN)',
#   '앨범명': "부석순 1st Single Album 'SECOND WIND'",
#   '순위': 17},
#  {'날짜': '20230603',
#   '곡명': 'LOVE DIVE',
#   '아티스트': 'IVE (아이브)',
#   '앨범명': 'LOVE DIVE',
#   '순위': 18},
#  {'날짜': '20230603',
#   '곡명': 'Dangerously',
#   '아티스트': 'Charlie Puth',
#   '앨범명': 'Nine Track Mind (Deluxe Edition)',
#   '순위': 19},
#  {'날짜': '20230603',
#   '곡명': '이브, 프시케 그리고 푸른 수염의 아내',
#   '아티스트': 'LE SSERAFIM (르세라핌)',
#   '앨범명': 'UNFORGIVEN',
#   '순위': 20},
#  {'날짜': '20230603',
#   '곡명': 'Attention',
#   '아티스트': 'NewJeans',
#   '앨범명': "NewJeans 1st EP 'New Jeans'",
#   '순위': 21},
#  {'날짜': '20230603',
#   '곡명': 'CHRISTIAN',
#   '아티스트': 'Zior Park',
#   '앨범명': 'WHERE DOES SASQUATCH LIVE? PART 1',
#   '순위': 22},
#  {'날짜': '20230603',
#   '곡명': 'ANTIFRAGILE',
#   '아티스트': 'LE SSERAFIM (르세라핌)',
#   '앨범명': 'ANTIFRAGILE',
#   '순위': 23},
#  {'날짜': '20230603',
#   '곡명': '헤어지자 말해요',
#   '아티스트': '박재정',
#   '앨범명': '1집 Alone',
#   '순위': 24},
#  {'날짜': '20230603',
#   '곡명': '사랑인가 봐',
#   '아티스트': '멜로망스 (MeloMance)',
#   '앨범명': '사랑인가 봐 (사내맞선 OST 스페셜 트랙)',
#   '순위': 25},
#  {'날짜': '20230603',
#   '곡명': 'NIGHT DANCER',
#   '아티스트': 'imase',
#   '앨범명': 'NIGHT DANCER',
#   '순위': 26},
#  {'날짜': '20230603',
#   '곡명': '건물 사이에 피어난 장미',
#   '아티스트': 'H1-KEY (하이키)',
#   '앨범명': 'H1-KEY 1st Mini Album (Rose Blossom)',
#   '순위': 27},
#  {'날짜': '20230603',
#   '곡명': '사랑은 늘 도망가',
#   '아티스트': '임영웅',
#   '앨범명': '신사와 아가씨 OST Part.2',
#   '순위': 28},
#  {'날짜': '20230603', '곡명': '물론', '아티스트': '허각', '앨범명': '물론', '순위': 29},
#  {'날짜': '20230603',
#   '곡명': 'TOMBOY',
#   '아티스트': '(여자)아이들',
#   '앨범명': 'I NEVER DIE',
#   '순위': 30},
#  {'날짜': '20230603',
#   '곡명': "That's Hilarious",
#   '아티스트': 'Charlie Puth',
#   '앨범명': 'CHARLIE',
#   '순위': 31},
#  {'날짜': '20230603',
#   '곡명': 'The Drum',
#   '아티스트': 'Alan Walker',
#   '앨범명': 'Walkerverse, Pt. I',
#   '순위': 32},
#  {'날짜': '20230603',
#   '곡명': 'Nxde',
#   '아티스트': '(여자)아이들',
#   '앨범명': 'I love',
#   '순위': 33},
#  {'날짜': '20230603',
#   '곡명': '취중고백',
#   '아티스트': '김민석 (멜로망스)',
#   '앨범명': '취중고백',
#   '순위': 34},
#  {'날짜': '20230603',
#   '곡명': 'Heaven (2023)',
#   '아티스트': '임재현',
#   '앨범명': '시작은 첫키스 OST Part.1',
#   '순위': 35},
#  {'날짜': '20230603',
#   '곡명': '너의 모든 순간',
#   '아티스트': '성시경',
#   '앨범명': '별에서 온 그대 OST Part.7 (SBS 수목드라마)',
#   '순위': 36},
#  {'날짜': '20230603', '곡명': '그라데이션', '아티스트': '10CM', '앨범명': '5.3', '순위': 37},
#  {'날짜': '20230603',
#   '곡명': '다정히 내 이름을 부르면',
#   '아티스트': '경서예지 & 전건호',
#   '앨범명': '다정히 내 이름을 부르면',
#   '순위': 38},
#  {'날짜': '20230603',
#   '곡명': 'KNOCK',
#   '아티스트': '이채연',
#   '앨범명': 'Over The Moon',
#   '순위': 39},
#  {'날짜': '20230603',
#   '곡명': '빛이 나는 너에게',
#   '아티스트': '던 (DAWN)',
#   '앨범명': '빛이 나는 너에게',
#   '순위': 40},
#  {'날짜': '20230603',
#   '곡명': 'Shut Down',
#   '아티스트': 'BLACKPINK',
#   '앨범명': 'BORN PINK',
#   '순위': 41},
#  {'날짜': '20230603',
#   '곡명': '새삥 (Prod. by ZICO) (Feat. 호미들)',
#   '아티스트': '지코 (ZICO)',
#   '앨범명': '스트릿 맨 파이터(SMF) Original Vol.3 (계급미션)',
#   '순위': 42},
#  {'날짜': '20230603',
#   '곡명': '그때 그 순간 그대로 (그그그)',
#   '아티스트': 'WSG워너비 (가야G)',
#   '앨범명': 'WSG워너비 1집',
#   '순위': 43},
#  {'날짜': '20230603',
#   '곡명': 'Stay',
#   '아티스트': 'The Kid LAROI & Justin Bieber',
#   '앨범명': 'Stay',
#   '순위': 44},
#  {'날짜': '20230603', '곡명': '나의 X에게', '아티스트': '경서', '앨범명': '나의 X에게', '순위': 45},
#  {'날짜': '20230603',
#   '곡명': 'When I Get Old',
#   '아티스트': 'Christopher & 청하',
#   '앨범명': 'When I Get Old',
#   '순위': 46},
#  {'날짜': '20230603',
#   '곡명': 'Monologue',
#   '아티스트': '테이 (Tei)',
#   '앨범명': 'Monologue',
#   '순위': 47},
#  {'날짜': '20230603',
#   '곡명': '사랑..그게 뭔데',
#   '아티스트': '지아 (Zia)',
#   '앨범명': '사랑..그게 뭔데',
#   '순위': 48},
#  {'날짜': '20230603',
#   '곡명': 'ELEVEN',
#   '아티스트': 'IVE (아이브)',
#   '앨범명': 'ELEVEN',
#   '순위': 49},
#  {'날짜': '20230603',
#   '곡명': '해요 (2022)',
#   '아티스트': '#안녕',
#   '앨범명': '해요 (2022)',
#   '순위': 50},
#  {'날짜': '20230603',
#   '곡명': 'Pink Venom',
#   '아티스트': 'BLACKPINK',
#   '앨범명': 'BORN PINK',
#   '순위': 51},
#  {'날짜': '20230603',
#   '곡명': '우리들의 블루스',
#   '아티스트': '임영웅',
#   '앨범명': 'IM HERO',
#   '순위': 52},
#  {'날짜': '20230603',
#   '곡명': '오르트구름',
#   '아티스트': '윤하 (YOUNHA)',
#   '앨범명': "YOUNHA 6th Album 'END THEORY'",
#   '순위': 53},
#  {'날짜': '20230603',
#   '곡명': 'Allergy',
#   '아티스트': '(여자)아이들',
#   '앨범명': 'I feel',
#   '순위': 54},
#  {'날짜': '20230603', '곡명': '신호등', '아티스트': '이무진', '앨범명': '신호등', '순위': 55},
#  {'날짜': '20230603',
#   '곡명': '사랑하기 싫어',
#   '아티스트': '지아 (Zia)',
#   '앨범명': '사랑하기 싫어',
#   '순위': 56},
#  {'날짜': '20230603',
#   '곡명': 'Loving You Girl (Feat. Hkeem)',
#   '아티스트': 'Peder Elias',
#   '앨범명': 'Love & Loneliness',
#   '순위': 57},
#  {'날짜': '20230603', '곡명': '내가 아니라도', '아티스트': '주호', '앨범명': '내가 아니라도', '순위': 58},
#  {'날짜': '20230603',
#   '곡명': 'Dynamite',
#   '아티스트': '방탄소년단',
#   '앨범명': 'Dynamite (DayTime Ver.)',
#   '순위': 59},
#  {'날짜': '20230603',
#   '곡명': '2002',
#   '아티스트': 'Anne-Marie',
#   '앨범명': 'Speak Your Mind (Deluxe)',
#   '순위': 60},
#  {'날짜': '20230603',
#   '곡명': '잠깐 시간 될까',
#   '아티스트': '이무진',
#   '앨범명': '잠깐 시간 될까',
#   '순위': 61},
#  {'날짜': '20230603',
#   '곡명': 'FEARLESS',
#   '아티스트': 'LE SSERAFIM (르세라핌)',
#   '앨범명': 'FEARLESS',
#   '순위': 62},
#  {'날짜': '20230603',
#   '곡명': '나의 바람 (Wind And Wish)',
#   '아티스트': '비투비',
#   '앨범명': 'WIND AND WISH',
#   '순위': 63},
#  {'날짜': '20230603',
#   '곡명': '주저하는 연인들을 위해',
#   '아티스트': '잔나비',
#   '앨범명': '전설',
#   '순위': 64},
#  {'날짜': '20230603',
#   '곡명': '보고싶었어',
#   '아티스트': 'WSG워너비 (4FIRE)',
#   '앨범명': 'WSG워너비 1집',
#   '순위': 65},
#  {'날짜': '20230603',
#   '곡명': '정이라고 하자 (Feat. 10CM)',
#   '아티스트': 'BIG Naughty (서동현)',
#   '앨범명': '정이라고 하자',
#   '순위': 66},
#  {'날짜': '20230603',
#   '곡명': '찬란한 하루',
#   '아티스트': '멜로망스 (MeloMance)',
#   '앨범명': '찬란한 하루',
#   '순위': 67},
#  {'날짜': '20230603',
#   '곡명': '이제 나만 믿어요',
#   '아티스트': '임영웅',
#   '앨범명': '내일은 미스터트롯 우승자 특전곡',
#   '순위': 68},
#  {'날짜': '20230603',
#   '곡명': 'Cookie',
#   '아티스트': 'NewJeans',
#   '앨범명': "NewJeans 1st EP 'New Jeans'",
#   '순위': 69},
#  {'날짜': '20230603',
#   '곡명': '모든 날, 모든 순간 (Every day, Every Moment)',
#   '아티스트': '폴킴',
#   '앨범명': "'키스 먼저 할까요?' OST Part. 3 (SBS 월화드라마)",
#   '순위': 70},
#  {'날짜': '20230603',
#   '곡명': 'Off My Face',
#   '아티스트': 'Justin Bieber',
#   '앨범명': 'Justice',
#   '순위': 71},
#  {'날짜': '20230603',
#   '곡명': 'VIBE (Feat. Jimin of BTS)',
#   '아티스트': '태양',
#   '앨범명': 'VIBE',
#   '순위': 72},
#  {'날짜': '20230603',
#   '곡명': 'Thirsty',
#   '아티스트': 'aespa',
#   '앨범명': 'MY WORLD - The 3rd Mini Album',
#   '순위': 73},
#  {'날짜': '20230603',
#   '곡명': '밤하늘의 별을 (2020)',
#   '아티스트': '경서',
#   '앨범명': '밤하늘의 별을 (2020)',
#   '순위': 74},
#  {'날짜': '20230603',
#   '곡명': '다시 만날 수 있을까',
#   '아티스트': '임영웅',
#   '앨범명': 'IM HERO',
#   '순위': 75},
#  {'날짜': '20230603',
#   '곡명': 'NOT SORRY (Feat. pH-1) (Prod. by Slom)',
#   '아티스트': '이영지',
#   '앨범명': '쇼미더머니 11 Episode 3',
#   '순위': 76},
#  {'날짜': '20230603',
#   '곡명': 'Unholy',
#   '아티스트': 'Sam Smith & Kim Petras',
#   '앨범명': 'Unholy',
#   '순위': 77},
#  {'날짜': '20230603',
#   '곡명': 'Say I Love You',
#   '아티스트': '우디 (Woody)',
#   '앨범명': 'Say I Love You (Re : WIND 4MEN Vol.04)',
#   '순위': 78},
#  {'날짜': '20230603',
#   '곡명': '흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야',
#   '아티스트': '장범준',
#   '앨범명': '멜로가 체질 OST Part 3 (JTBC 금토 드라마)',
#   '순위': 79},
#  {'날짜': '20230603',
#   '곡명': 'Every Second',
#   '아티스트': 'Mina Okabe',
#   '앨범명': 'Every Second',
#   '순위': 80},
#  {'날짜': '20230603',
#   '곡명': 'Dreamers (Music from the FIFA World Cup Qatar 2022 Official Soundtrack) (Feat. FIFA Sound)',
#   '아티스트': '정국 & 방탄소년단',
#   '앨범명': 'Dreamers (Music from the FIFA World Cup Qatar 2022 Official Soundtrack)',
#   '순위': 81},
#  {'날짜': '20230603',
#   '곡명': '봄여름가을겨울 (Still Life)',
#   '아티스트': 'BIGBANG (빅뱅)',
#   '앨범명': '봄여름가을겨울 (Still Life)',
#   '순위': 82},
#  {'날짜': '20230603', '곡명': '희재', '아티스트': '성시경', '앨범명': '국화꽃 향기 OST', '순위': 83},
#  {'날짜': '20230603',
#   '곡명': 'London Boy',
#   '아티스트': '임영웅',
#   '앨범명': 'Polaroid',
#   '순위': 84},
#  {'날짜': '20230603',
#   '곡명': 'INVU',
#   '아티스트': '태연 (TAEYEON)',
#   '앨범명': 'INVU - The 3rd Album',
#   '순위': 85},
#  {'날짜': '20230603',
#   '곡명': 'Candy',
#   '아티스트': 'NCT DREAM',
#   '앨범명': 'Candy - Winter Special Mini Album',
#   '순위': 86},
#  {'날짜': '20230603',
#   '곡명': '딱 10CM만',
#   '아티스트': '10CM & BIG Naughty (서동현)',
#   '앨범명': '딱 10CM만',
#   '순위': 87},
#  {'날짜': '20230603',
#   '곡명': 'Bad Habits',
#   '아티스트': 'Ed Sheeran',
#   '앨범명': '=',
#   '순위': 88},
#  {'날짜': '20230603',
#   '곡명': 'LOVE me',
#   '아티스트': "BE'O (비오)",
#   '앨범명': 'LOVE me',
#   '순위': 89},
#  {'날짜': '20230603',
#   '곡명': 'Blueming',
#   '아티스트': '아이유 (IU)',
#   '앨범명': 'Love poem',
#   '순위': 90},
#  {'날짜': '20230603',
#   '곡명': '첫 키스에 내 심장은 120BPM',
#   '아티스트': '경서',
#   '앨범명': 'ONGOING',
#   '순위': 91},
#  {'날짜': '20230603',
#   '곡명': 'Weekend',
#   '아티스트': '태연 (TAEYEON)',
#   '앨범명': 'Weekend',
#   '순위': 92},
#  {'날짜': '20230603',
#   '곡명': 'That That (Prod. & Feat. SUGA of BTS)',
#   '아티스트': '싸이 (Psy)',
#   '앨범명': '싸다9',
#   '순위': 93},
#  {'날짜': '20230603',
#   '곡명': 'Butter',
#   '아티스트': '방탄소년단',
#   '앨범명': 'Butter',
#   '순위': 94},
#  {'날짜': '20230603',
#   '곡명': '에잇 (Prod. & Feat. SUGA of BTS)',
#   '아티스트': '아이유 (IU)',
#   '앨범명': '에잇',
#   '순위': 95},
#  {'날짜': '20230603',
#   '곡명': 'Love Me Like This',
#   '아티스트': 'NMIXX',
#   '앨범명': 'expérgo',
#   '순위': 96},
#  {'날짜': '20230603',
#   '곡명': 'Rush Hour (Feat. j-hope of BTS)',
#   '아티스트': 'Crush',
#   '앨범명': 'Rush Hour',
#   '순위': 97},
#  {'날짜': '20230603',
#   '곡명': 'Ai Wo Tsutaetaidatoka',
#   '아티스트': 'aimyon',
#   '앨범명': 'Ai Wo Tsutaetaidatoka',
#   '순위': 98},
#  {'날짜': '20230603',
#   '곡명': 'Bad',
#   '아티스트': 'Christopher',
#   '앨범명': 'Under the Surface',
#   '순위': 99},
#  {'날짜': '20230603',
#   '곡명': '고백',
#   '아티스트': '멜로망스 (MeloMance)',
#   '앨범명': "세 번째 '고백'",
#   '순위': 100},
#  {'날짜': '20230604',
#   '곡명': '퀸카 (Queencard)',
#   '아티스트': '(여자)아이들',
#   '앨범명': 'I feel',
#   '순위': 1},
#  {'날짜': '20230604',
#   '곡명': 'I AM',
#   '아티스트': 'IVE (아이브)',
#   '앨범명': "I've IVE",
#   '순위': 2},
#  {'날짜': '20230604',
#   '곡명': 'Spicy',
#   '아티스트': 'aespa',
#   '앨범명': 'MY WORLD - The 3rd Mini Album',
#   '순위': 3},
#  {'날짜': '20230604',
#   '곡명': 'Kitsch',
#   '아티스트': 'IVE (아이브)',
#   '앨범명': "I've IVE",
#   '순위': 4},
#  {'날짜': '20230604',
#   '곡명': 'UNFORGIVEN (Feat. Nile Rodgers)',
#   '아티스트': 'LE SSERAFIM (르세라핌)',
#   '앨범명': 'UNFORGIVEN',
#   '순위': 5},
#  {'날짜': '20230604', '곡명': '꽃', '아티스트': '지수 (JISOO)', '앨범명': 'ME', '순위': 6},
#  {'날짜': '20230604',
#   '곡명': 'Hype boy',
#   '아티스트': 'NewJeans',
#   '앨범명': "NewJeans 1st EP 'New Jeans'",
#   '순위': 7},
#  {'날짜': '20230604',
#   '곡명': 'Ditto',
#   '아티스트': 'NewJeans',
#   '앨범명': "NewJeans 'OMG'",
#   '순위': 8},
#  {'날짜': '20230604',
#   '곡명': '사건의 지평선',
#   '아티스트': '윤하 (YOUNHA)',
#   '앨범명': "YOUNHA 6th Album Repackage 'END THEORY : Final Edition'",
#   '순위': 9},
#  {'날짜': '20230604',
#   '곡명': 'Cupid',
#   '아티스트': 'FIFTY FIFTY',
#   '앨범명': 'The Beginning : Cupid',
#   '순위': 10},
#  {'날짜': '20230604',
#   '곡명': '손오공',
#   '아티스트': '세븐틴 (SEVENTEEN)',
#   '앨범명': "SEVENTEEN 10th Mini Album 'FML'",
#   '순위': 11},
#  {'날짜': '20230604',
#   '곡명': "I Don't Think That I Like Her",
#   '아티스트': 'Charlie Puth',
#   '앨범명': 'CHARLIE',
#   '순위': 12},
#  {'날짜': '20230604',
#   '곡명': 'After LIKE',
#   '아티스트': 'IVE (아이브)',
#   '앨범명': 'After LIKE',
#   '순위': 13},
#  {'날짜': '20230604',
#   '곡명': '이브, 프시케 그리고 푸른 수염의 아내',
#   '아티스트': 'LE SSERAFIM (르세라핌)',
#   '앨범명': 'UNFORGIVEN',
#   '순위': 14},
#  {'날짜': '20230604',
#   '곡명': 'Teddy Bear',
#   '아티스트': 'STAYC (스테이씨)',
#   '앨범명': 'Teddy Bear',
#   '순위': 15},
#  {'날짜': '20230604',
#   '곡명': '심 (心)',
#   '아티스트': 'DK (디셈버)',
#   '앨범명': '심 (心)',
#   '순위': 16},
#  {'날짜': '20230604',
#   '곡명': 'OMG',
#   '아티스트': 'NewJeans',
#   '앨범명': "NewJeans 'OMG'",
#   '순위': 17},
#  {'날짜': '20230604',
#   '곡명': '파이팅 해야지 (Feat. 이영지)',
#   '아티스트': '부석순 (SEVENTEEN)',
#   '앨범명': "부석순 1st Single Album 'SECOND WIND'",
#   '순위': 18},
#  {'날짜': '20230604',
#   '곡명': 'LOVE DIVE',
#   '아티스트': 'IVE (아이브)',
#   '앨범명': 'LOVE DIVE',
#   '순위': 19},
#  {'날짜': '20230604',
#   '곡명': 'Dangerously',
#   '아티스트': 'Charlie Puth',
#   '앨범명': 'Nine Track Mind (Deluxe Edition)',
#   '순위': 20},
#  {'날짜': '20230604',
#   '곡명': '사실말야내가말야그게그러니까말이야',
#   '아티스트': '케이시 (Kassy)',
#   '앨범명': '사실말야내가말야그게그러니까말이야',
#   '순위': 21},
#  {'날짜': '20230604',
#   '곡명': 'Attention',
#   '아티스트': 'NewJeans',
#   '앨범명': "NewJeans 1st EP 'New Jeans'",
#   '순위': 22},
#  {'날짜': '20230604',
#   '곡명': 'CHRISTIAN',
#   '아티스트': 'Zior Park',
#   '앨범명': 'WHERE DOES SASQUATCH LIVE? PART 1',
#   '순위': 23},
#  {'날짜': '20230604',
#   '곡명': 'ANTIFRAGILE',
#   '아티스트': 'LE SSERAFIM (르세라핌)',
#   '앨범명': 'ANTIFRAGILE',
#   '순위': 24},
#  {'날짜': '20230604',
#   '곡명': '헤어지자 말해요',
#   '아티스트': '박재정',
#   '앨범명': '1집 Alone',
#   '순위': 25},
#  {'날짜': '20230604',
#   '곡명': '사랑인가 봐',
#   '아티스트': '멜로망스 (MeloMance)',
#   '앨범명': '사랑인가 봐 (사내맞선 OST 스페셜 트랙)',
#   '순위': 26},
#  {'날짜': '20230604',
#   '곡명': '건물 사이에 피어난 장미',
#   '아티스트': 'H1-KEY (하이키)',
#   '앨범명': 'H1-KEY 1st Mini Album (Rose Blossom)',
#   '순위': 27},
#  {'날짜': '20230604',
#   '곡명': 'NIGHT DANCER',
#   '아티스트': 'imase',
#   '앨범명': 'NIGHT DANCER',
#   '순위': 28},
#  {'날짜': '20230604',
#   '곡명': '사랑은 늘 도망가',
#   '아티스트': '임영웅',
#   '앨범명': '신사와 아가씨 OST Part.2',
#   '순위': 29},
#  {'날짜': '20230604', '곡명': '물론', '아티스트': '허각', '앨범명': '물론', '순위': 30},
#  {'날짜': '20230604',
#   '곡명': 'TOMBOY',
#   '아티스트': '(여자)아이들',
#   '앨범명': 'I NEVER DIE',
#   '순위': 31},
#  {'날짜': '20230604',
#   '곡명': "That's Hilarious",
#   '아티스트': 'Charlie Puth',
#   '앨범명': 'CHARLIE',
#   '순위': 32},
#  {'날짜': '20230604',
#   '곡명': 'The Drum',
#   '아티스트': 'Alan Walker',
#   '앨범명': 'Walkerverse, Pt. I',
#   '순위': 33},
#  {'날짜': '20230604',
#   '곡명': 'Nxde',
#   '아티스트': '(여자)아이들',
#   '앨범명': 'I love',
#   '순위': 34},
#  {'날짜': '20230604',
#   '곡명': '다정히 내 이름을 부르면',
#   '아티스트': '경서예지 & 전건호',
#   '앨범명': '다정히 내 이름을 부르면',
#   '순위': 35},
#  {'날짜': '20230604',
#   '곡명': 'Stay',
#   '아티스트': 'The Kid LAROI & Justin Bieber',
#   '앨범명': 'Stay',
#   '순위': 36},
#  {'날짜': '20230604',
#   '곡명': 'Shut Down',
#   '아티스트': 'BLACKPINK',
#   '앨범명': 'BORN PINK',
#   '순위': 37},
#  {'날짜': '20230604',
#   '곡명': '빛이 나는 너에게',
#   '아티스트': '던 (DAWN)',
#   '앨범명': '빛이 나는 너에게',
#   '순위': 38},
#  {'날짜': '20230604',
#   '곡명': 'Heaven (2023)',
#   '아티스트': '임재현',
#   '앨범명': '시작은 첫키스 OST Part.1',
#   '순위': 39},
#  {'날짜': '20230604',
#   '곡명': 'KNOCK',
#   '아티스트': '이채연',
#   '앨범명': 'Over The Moon',
#   '순위': 40},
#  {'날짜': '20230604',
#   '곡명': '새삥 (Prod. by ZICO) (Feat. 호미들)',
#   '아티스트': '지코 (ZICO)',
#   '앨범명': '스트릿 맨 파이터(SMF) Original Vol.3 (계급미션)',
#   '순위': 41},
#  {'날짜': '20230604',
#   '곡명': '취중고백',
#   '아티스트': '김민석 (멜로망스)',
#   '앨범명': '취중고백',
#   '순위': 42},
#  {'날짜': '20230604', '곡명': '그라데이션', '아티스트': '10CM', '앨범명': '5.3', '순위': 43},
#  {'날짜': '20230604',
#   '곡명': 'When I Get Old',
#   '아티스트': 'Christopher & 청하',
#   '앨범명': 'When I Get Old',
#   '순위': 44},
#  {'날짜': '20230604',
#   '곡명': '너의 모든 순간',
#   '아티스트': '성시경',
#   '앨범명': '별에서 온 그대 OST Part.7 (SBS 수목드라마)',
#   '순위': 45},
#  {'날짜': '20230604', '곡명': '나의 X에게', '아티스트': '경서', '앨범명': '나의 X에게', '순위': 46},
#  {'날짜': '20230604',
#   '곡명': '그때 그 순간 그대로 (그그그)',
#   '아티스트': 'WSG워너비 (가야G)',
#   '앨범명': 'WSG워너비 1집',
#   '순위': 47},
#  {'날짜': '20230604',
#   '곡명': 'Allergy',
#   '아티스트': '(여자)아이들',
#   '앨범명': 'I feel',
#   '순위': 48},
#  {'날짜': '20230604',
#   '곡명': 'ELEVEN',
#   '아티스트': 'IVE (아이브)',
#   '앨범명': 'ELEVEN',
#   '순위': 49},
#  {'날짜': '20230604',
#   '곡명': 'Monologue',
#   '아티스트': '테이 (Tei)',
#   '앨범명': 'Monologue',
#   '순위': 50},
#  {'날짜': '20230604',
#   '곡명': '우리들의 블루스',
#   '아티스트': '임영웅',
#   '앨범명': 'IM HERO',
#   '순위': 51},
#  {'날짜': '20230604',
#   '곡명': '사랑..그게 뭔데',
#   '아티스트': '지아 (Zia)',
#   '앨범명': '사랑..그게 뭔데',
#   '순위': 52},
#  {'날짜': '20230604',
#   '곡명': 'Pink Venom',
#   '아티스트': 'BLACKPINK',
#   '앨범명': 'BORN PINK',
#   '순위': 53},
#  {'날짜': '20230604',
#   '곡명': '해요 (2022)',
#   '아티스트': '#안녕',
#   '앨범명': '해요 (2022)',
#   '순위': 54},
#  {'날짜': '20230604',
#   '곡명': '오르트구름',
#   '아티스트': '윤하 (YOUNHA)',
#   '앨범명': "YOUNHA 6th Album 'END THEORY'",
#   '순위': 55},
#  {'날짜': '20230604',
#   '곡명': '찬란한 하루',
#   '아티스트': '멜로망스 (MeloMance)',
#   '앨범명': '찬란한 하루',
#   '순위': 56},
#  {'날짜': '20230604',
#   '곡명': 'Dynamite',
#   '아티스트': '방탄소년단',
#   '앨범명': 'Dynamite (DayTime Ver.)',
#   '순위': 57},
#  {'날짜': '20230604',
#   '곡명': '잠깐 시간 될까',
#   '아티스트': '이무진',
#   '앨범명': '잠깐 시간 될까',
#   '순위': 58},
#  {'날짜': '20230604',
#   '곡명': 'Loving You Girl (Feat. Hkeem)',
#   '아티스트': 'Peder Elias',
#   '앨범명': 'Love & Loneliness',
#   '순위': 59},
#  {'날짜': '20230604', '곡명': '신호등', '아티스트': '이무진', '앨범명': '신호등', '순위': 60},
#  {'날짜': '20230604',
#   '곡명': '사랑하기 싫어',
#   '아티스트': '지아 (Zia)',
#   '앨범명': '사랑하기 싫어',
#   '순위': 61},
#  {'날짜': '20230604', '곡명': '내가 아니라도', '아티스트': '주호', '앨범명': '내가 아니라도', '순위': 62},
#  {'날짜': '20230604',
#   '곡명': '2002',
#   '아티스트': 'Anne-Marie',
#   '앨범명': 'Speak Your Mind (Deluxe)',
#   '순위': 63},
#  {'날짜': '20230604',
#   '곡명': '나의 바람 (Wind And Wish)',
#   '아티스트': '비투비',
#   '앨범명': 'WIND AND WISH',
#   '순위': 64},
#  {'날짜': '20230604',
#   '곡명': 'FEARLESS',
#   '아티스트': 'LE SSERAFIM (르세라핌)',
#   '앨범명': 'FEARLESS',
#   '순위': 65},
#  {'날짜': '20230604',
#   '곡명': '주저하는 연인들을 위해',
#   '아티스트': '잔나비',
#   '앨범명': '전설',
#   '순위': 66},
#  {'날짜': '20230604',
#   '곡명': '이제 나만 믿어요',
#   '아티스트': '임영웅',
#   '앨범명': '내일은 미스터트롯 우승자 특전곡',
#   '순위': 67},
#  {'날짜': '20230604',
#   '곡명': '정이라고 하자 (Feat. 10CM)',
#   '아티스트': 'BIG Naughty (서동현)',
#   '앨범명': '정이라고 하자',
#   '순위': 68},
#  {'날짜': '20230604',
#   '곡명': 'Thirsty',
#   '아티스트': 'aespa',
#   '앨범명': 'MY WORLD - The 3rd Mini Album',
#   '순위': 69},
#  {'날짜': '20230604',
#   '곡명': 'Cookie',
#   '아티스트': 'NewJeans',
#   '앨범명': "NewJeans 1st EP 'New Jeans'",
#   '순위': 70},
#  {'날짜': '20230604',
#   '곡명': '보고싶었어',
#   '아티스트': 'WSG워너비 (4FIRE)',
#   '앨범명': 'WSG워너비 1집',
#   '순위': 71},
#  {'날짜': '20230604',
#   '곡명': '모든 날, 모든 순간 (Every day, Every Moment)',
#   '아티스트': '폴킴',
#   '앨범명': "'키스 먼저 할까요?' OST Part. 3 (SBS 월화드라마)",
#   '순위': 72},
#  {'날짜': '20230604',
#   '곡명': '다시 만날 수 있을까',
#   '아티스트': '임영웅',
#   '앨범명': 'IM HERO',
#   '순위': 73},
#  {'날짜': '20230604',
#   '곡명': 'VIBE (Feat. Jimin of BTS)',
#   '아티스트': '태양',
#   '앨범명': 'VIBE',
#   '순위': 74},
#  {'날짜': '20230604',
#   '곡명': 'Off My Face',
#   '아티스트': 'Justin Bieber',
#   '앨범명': 'Justice',
#   '순위': 75},
#  {'날짜': '20230604',
#   '곡명': '밤하늘의 별을 (2020)',
#   '아티스트': '경서',
#   '앨범명': '밤하늘의 별을 (2020)',
#   '순위': 76},
#  {'날짜': '20230604',
#   '곡명': 'London Boy',
#   '아티스트': '임영웅',
#   '앨범명': 'Polaroid',
#   '순위': 77},
#  {'날짜': '20230604',
#   '곡명': 'Unholy',
#   '아티스트': 'Sam Smith & Kim Petras',
#   '앨범명': 'Unholy',
#   '순위': 78},
#  {'날짜': '20230604',
#   '곡명': 'NOT SORRY (Feat. pH-1) (Prod. by Slom)',
#   '아티스트': '이영지',
#   '앨범명': '쇼미더머니 11 Episode 3',
#   '순위': 79},
#  {'날짜': '20230604',
#   '곡명': '흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야',
#   '아티스트': '장범준',
#   '앨범명': '멜로가 체질 OST Part 3 (JTBC 금토 드라마)',
#   '순위': 80},
#  {'날짜': '20230604',
#   '곡명': 'Every Second',
#   '아티스트': 'Mina Okabe',
#   '앨범명': 'Every Second',
#   '순위': 81},
#  {'날짜': '20230604', '곡명': '희재', '아티스트': '성시경', '앨범명': '국화꽃 향기 OST', '순위': 82},
#  {'날짜': '20230604',
#   '곡명': '봄여름가을겨울 (Still Life)',
#   '아티스트': 'BIGBANG (빅뱅)',
#   '앨범명': '봄여름가을겨울 (Still Life)',
#   '순위': 83},
#  {'날짜': '20230604',
#   '곡명': 'Dreamers (Music from the FIFA World Cup Qatar 2022 Official Soundtrack) (Feat. FIFA Sound)',
#   '아티스트': '정국 & 방탄소년단',
#   '앨범명': 'Dreamers (Music from the FIFA World Cup Qatar 2022 Official Soundtrack)',
#   '순위': 84},
#  {'날짜': '20230604',
#   '곡명': 'Say I Love You',
#   '아티스트': '우디 (Woody)',
#   '앨범명': 'Say I Love You (Re : WIND 4MEN Vol.04)',
#   '순위': 85},
#  {'날짜': '20230604',
#   '곡명': '첫 키스에 내 심장은 120BPM',
#   '아티스트': '경서',
#   '앨범명': 'ONGOING',
#   '순위': 86},
#  {'날짜': '20230604',
#   '곡명': 'Weekend',
#   '아티스트': '태연 (TAEYEON)',
#   '앨범명': 'Weekend',
#   '순위': 87},
#  {'날짜': '20230604',
#   '곡명': 'INVU',
#   '아티스트': '태연 (TAEYEON)',
#   '앨범명': 'INVU - The 3rd Album',
#   '순위': 88},
#  {'날짜': '20230604',
#   '곡명': '딱 10CM만',
#   '아티스트': '10CM & BIG Naughty (서동현)',
#   '앨범명': '딱 10CM만',
#   '순위': 89},
#  {'날짜': '20230604',
#   '곡명': 'Bad Habits',
#   '아티스트': 'Ed Sheeran',
#   '앨범명': '=',
#   '순위': 90},
#  {'날짜': '20230604',
#   '곡명': 'LOVE me',
#   '아티스트': "BE'O (비오)",
#   '앨범명': 'LOVE me',
#   '순위': 91},
#  {'날짜': '20230604',
#   '곡명': 'Candy',
#   '아티스트': 'NCT DREAM',
#   '앨범명': 'Candy - Winter Special Mini Album',
#   '순위': 92},
#  {'날짜': '20230604',
#   '곡명': '고백',
#   '아티스트': '멜로망스 (MeloMance)',
#   '앨범명': "세 번째 '고백'",
#   '순위': 93},
#  {'날짜': '20230604',
#   '곡명': 'That That (Prod. & Feat. SUGA of BTS)',
#   '아티스트': '싸이 (Psy)',
#   '앨범명': '싸다9',
#   '순위': 94},
#  {'날짜': '20230604',
#   '곡명': '특',
#   '아티스트': 'Stray Kids (스트레이 키즈)',
#   '앨범명': '★★★★★ (5-STAR)',
#   '순위': 95},
#  {'날짜': '20230604', '곡명': '무지개', '아티스트': '임영웅', '앨범명': 'IM HERO', '순위': 96},
#  {'날짜': '20230604',
#   '곡명': 'Ai Wo Tsutaetaidatoka',
#   '아티스트': 'aimyon',
#   '앨범명': 'Ai Wo Tsutaetaidatoka',
#   '순위': 97},
#  {'날짜': '20230604',
#   '곡명': 'Celebrity',
#   '아티스트': '아이유 (IU)',
#   '앨범명': "IU 5th Album 'LILAC'",
#   '순위': 98},
#  {'날짜': '20230604',
#   '곡명': "That's Not How This Works (Feat. Dan ＋ Shay)",
#   '아티스트': 'Charlie Puth',
#   '앨범명': "That's Not How This Works",
#   '순위': 99},
#  {'날짜': '20230604',
#   '곡명': 'Bad',
#   '아티스트': 'Christopher',
#   '앨범명': 'Under the Surface',
#   '순위': 100},
#  {'날짜': '20230605',
#   '곡명': '퀸카 (Queencard)',
#   '아티스트': '(여자)아이들',
#   '앨범명': 'I feel',
#   '순위': 1},
#  {'날짜': '20230605',
#   '곡명': 'I AM',
#   '아티스트': 'IVE (아이브)',
#   '앨범명': "I've IVE",
#   '순위': 2},
#  {'날짜': '20230605',
#   '곡명': 'Spicy',
#   '아티스트': 'aespa',
#   '앨범명': 'MY WORLD - The 3rd Mini Album',
#   '순위': 3},
#  {'날짜': '20230605',
#   '곡명': 'Kitsch',
#   '아티스트': 'IVE (아이브)',
#   '앨범명': "I've IVE",
#   '순위': 4},
#  {'날짜': '20230605',
#   '곡명': 'UNFORGIVEN (Feat. Nile Rodgers)',
#   '아티스트': 'LE SSERAFIM (르세라핌)',
#   '앨범명': 'UNFORGIVEN',
#   '순위': 5},
#  {'날짜': '20230605', '곡명': '꽃', '아티스트': '지수 (JISOO)', '앨범명': 'ME', '순위': 6},
#  {'날짜': '20230605',
#   '곡명': 'Hype boy',
#   '아티스트': 'NewJeans',
#   '앨범명': "NewJeans 1st EP 'New Jeans'",
#   '순위': 7},
#  {'날짜': '20230605',
#   '곡명': 'Ditto',
#   '아티스트': 'NewJeans',
#   '앨범명': "NewJeans 'OMG'",
#   '순위': 8},
#  {'날짜': '20230605',
#   '곡명': '사건의 지평선',
#   '아티스트': '윤하 (YOUNHA)',
#   '앨범명': "YOUNHA 6th Album Repackage 'END THEORY : Final Edition'",
#   '순위': 9},
#  {'날짜': '20230605',
#   '곡명': '이브, 프시케 그리고 푸른 수염의 아내',
#   '아티스트': 'LE SSERAFIM (르세라핌)',
#   '앨범명': 'UNFORGIVEN',
#   '순위': 10},
#  {'날짜': '20230605',
#   '곡명': '손오공',
#   '아티스트': '세븐틴 (SEVENTEEN)',
#   '앨범명': "SEVENTEEN 10th Mini Album 'FML'",
#   '순위': 11},
#  {'날짜': '20230605',
#   '곡명': 'Cupid',
#   '아티스트': 'FIFTY FIFTY',
#   '앨범명': 'The Beginning : Cupid',
#   '순위': 12},
#  {'날짜': '20230605',
#   '곡명': "I Don't Think That I Like Her",
#   '아티스트': 'Charlie Puth',
#   '앨범명': 'CHARLIE',
#   '순위': 13},
#  {'날짜': '20230605',
#   '곡명': 'After LIKE',
#   '아티스트': 'IVE (아이브)',
#   '앨범명': 'After LIKE',
#   '순위': 14},
#  {'날짜': '20230605',
#   '곡명': 'Teddy Bear',
#   '아티스트': 'STAYC (스테이씨)',
#   '앨범명': 'Teddy Bear',
#   '순위': 15},
#  {'날짜': '20230605',
#   '곡명': '심 (心)',
#   '아티스트': 'DK (디셈버)',
#   '앨범명': '심 (心)',
#   '순위': 16},
#  {'날짜': '20230605',
#   '곡명': 'OMG',
#   '아티스트': 'NewJeans',
#   '앨범명': "NewJeans 'OMG'",
#   '순위': 17},
#  {'날짜': '20230605',
#   '곡명': 'Dangerously',
#   '아티스트': 'Charlie Puth',
#   '앨범명': 'Nine Track Mind (Deluxe Edition)',
#   '순위': 18},
#  {'날짜': '20230605',
#   '곡명': '파이팅 해야지 (Feat. 이영지)',
#   '아티스트': '부석순 (SEVENTEEN)',
#   '앨범명': "부석순 1st Single Album 'SECOND WIND'",
#   '순위': 19},
#  {'날짜': '20230605',
#   '곡명': 'LOVE DIVE',
#   '아티스트': 'IVE (아이브)',
#   '앨범명': 'LOVE DIVE',
#   '순위': 20},
#  {'날짜': '20230605',
#   '곡명': 'Attention',
#   '아티스트': 'NewJeans',
#   '앨범명': "NewJeans 1st EP 'New Jeans'",
#   '순위': 21},
#  {'날짜': '20230605',
#   '곡명': 'CHRISTIAN',
#   '아티스트': 'Zior Park',
#   '앨범명': 'WHERE DOES SASQUATCH LIVE? PART 1',
#   '순위': 22},
#  {'날짜': '20230605',
#   '곡명': 'ANTIFRAGILE',
#   '아티스트': 'LE SSERAFIM (르세라핌)',
#   '앨범명': 'ANTIFRAGILE',
#   '순위': 23},
#  {'날짜': '20230605',
#   '곡명': '헤어지자 말해요',
#   '아티스트': '박재정',
#   '앨범명': '1집 Alone',
#   '순위': 24},
#  {'날짜': '20230605',
#   '곡명': '사랑인가 봐',
#   '아티스트': '멜로망스 (MeloMance)',
#   '앨범명': '사랑인가 봐 (사내맞선 OST 스페셜 트랙)',
#   '순위': 25},
#  {'날짜': '20230605',
#   '곡명': '건물 사이에 피어난 장미',
#   '아티스트': 'H1-KEY (하이키)',
#   '앨범명': 'H1-KEY 1st Mini Album (Rose Blossom)',
#   '순위': 26},
#  {'날짜': '20230605',
#   '곡명': 'NIGHT DANCER',
#   '아티스트': 'imase',
#   '앨범명': 'NIGHT DANCER',
#   '순위': 27},
#  {'날짜': '20230605',
#   '곡명': '사랑은 늘 도망가',
#   '아티스트': '임영웅',
#   '앨범명': '신사와 아가씨 OST Part.2',
#   '순위': 28},
#  {'날짜': '20230605',
#   '곡명': '사실말야내가말야그게그러니까말이야',
#   '아티스트': '케이시 (Kassy)',
#   '앨범명': '사실말야내가말야그게그러니까말이야',
#   '순위': 29},
#  {'날짜': '20230605', '곡명': '물론', '아티스트': '허각', '앨범명': '물론', '순위': 30},
#  {'날짜': '20230605',
#   '곡명': 'TOMBOY',
#   '아티스트': '(여자)아이들',
#   '앨범명': 'I NEVER DIE',
#   '순위': 31},
#  {'날짜': '20230605',
#   '곡명': "That's Hilarious",
#   '아티스트': 'Charlie Puth',
#   '앨범명': 'CHARLIE',
#   '순위': 32},
#  {'날짜': '20230605',
#   '곡명': 'Nxde',
#   '아티스트': '(여자)아이들',
#   '앨범명': 'I love',
#   '순위': 33},
#  {'날짜': '20230605',
#   '곡명': 'The Drum',
#   '아티스트': 'Alan Walker',
#   '앨범명': 'Walkerverse, Pt. I',
#   '순위': 34},
#  {'날짜': '20230605',
#   '곡명': '취중고백',
#   '아티스트': '김민석 (멜로망스)',
#   '앨범명': '취중고백',
#   '순위': 35},
#  {'날짜': '20230605',
#   '곡명': '다정히 내 이름을 부르면',
#   '아티스트': '경서예지 & 전건호',
#   '앨범명': '다정히 내 이름을 부르면',
#   '순위': 36},
#  {'날짜': '20230605',
#   '곡명': 'Shut Down',
#   '아티스트': 'BLACKPINK',
#   '앨범명': 'BORN PINK',
#   '순위': 37},
#  {'날짜': '20230605',
#   '곡명': '빛이 나는 너에게',
#   '아티스트': '던 (DAWN)',
#   '앨범명': '빛이 나는 너에게',
#   '순위': 38},
#  {'날짜': '20230605',
#   '곡명': 'Stay',
#   '아티스트': 'The Kid LAROI & Justin Bieber',
#   '앨범명': 'Stay',
#   '순위': 39},
#  {'날짜': '20230605',
#   '곡명': '새삥 (Prod. by ZICO) (Feat. 호미들)',
#   '아티스트': '지코 (ZICO)',
#   '앨범명': '스트릿 맨 파이터(SMF) Original Vol.3 (계급미션)',
#   '순위': 40},
#  {'날짜': '20230605',
#   '곡명': 'KNOCK',
#   '아티스트': '이채연',
#   '앨범명': 'Over The Moon',
#   '순위': 41},
#  {'날짜': '20230605',
#   '곡명': '너의 모든 순간',
#   '아티스트': '성시경',
#   '앨범명': '별에서 온 그대 OST Part.7 (SBS 수목드라마)',
#   '순위': 42},
#  {'날짜': '20230605',
#   '곡명': 'Heaven (2023)',
#   '아티스트': '임재현',
#   '앨범명': '시작은 첫키스 OST Part.1',
#   '순위': 43},
#  {'날짜': '20230605', '곡명': '그라데이션', '아티스트': '10CM', '앨범명': '5.3', '순위': 44},
#  {'날짜': '20230605',
#   '곡명': '그때 그 순간 그대로 (그그그)',
#   '아티스트': 'WSG워너비 (가야G)',
#   '앨범명': 'WSG워너비 1집',
#   '순위': 45},
#  {'날짜': '20230605',
#   '곡명': 'When I Get Old',
#   '아티스트': 'Christopher & 청하',
#   '앨범명': 'When I Get Old',
#   '순위': 46},
#  {'날짜': '20230605', '곡명': '나의 X에게', '아티스트': '경서', '앨범명': '나의 X에게', '순위': 47},
#  {'날짜': '20230605',
#   '곡명': '우리들의 블루스',
#   '아티스트': '임영웅',
#   '앨범명': 'IM HERO',
#   '순위': 48},
#  {'날짜': '20230605',
# ...
#  {'날짜': '20230609',
#   '곡명': 'Pink Venom',
#   '아티스트': 'BLACKPINK',
#   '앨범명': 'BORN PINK',
#   '순위': 50},
#  {'날짜': '20230609',
#   '곡명': 'Allergy',
#   '아티스트': '(여자)아이들',
#   '앨범명': 'I feel',
#   '순위': 51},
#  {'날짜': '20230609',
#   '곡명': '해요 (2022)',
#   '아티스트': '#안녕',
#   '앨범명': '해요 (2022)',
#   '순위': 52},
#  {'날짜': '20230609',
#   '곡명': 'ELEVEN',
#   '아티스트': 'IVE (아이브)',
#   '앨범명': 'ELEVEN',
#   '순위': 53},
#  {'날짜': '20230609',
#   '곡명': '오르트구름',
#   '아티스트': '윤하 (YOUNHA)',
#   '앨범명': "YOUNHA 6th Album 'END THEORY'",
#   '순위': 54},
#  {'날짜': '20230609',
#   '곡명': '우리들의 블루스',
#   '아티스트': '임영웅',
#   '앨범명': 'IM HERO',
#   '순위': 55},
#  {'날짜': '20230609',
#   '곡명': 'Dynamite',
#   '아티스트': '방탄소년단',
#   '앨범명': 'Dynamite (DayTime Ver.)',
#   '순위': 56},
#  {'날짜': '20230609', '곡명': '내가 아니라도', '아티스트': '주호', '앨범명': '내가 아니라도', '순위': 57},
#  {'날짜': '20230609',
#   '곡명': '사랑..그게 뭔데',
#   '아티스트': '지아 (Zia)',
#   '앨범명': '사랑..그게 뭔데',
#   '순위': 58},
#  {'날짜': '20230609',
#   '곡명': 'Loving You Girl (Feat. Hkeem)',
#   '아티스트': 'Peder Elias',
#   '앨범명': 'Love & Loneliness',
#   '순위': 59},
#  {'날짜': '20230609',
#   '곡명': '잠깐 시간 될까',
#   '아티스트': '이무진',
#   '앨범명': '잠깐 시간 될까',
#   '순위': 60},
#  {'날짜': '20230609',
#   '곡명': '사랑하기 싫어',
#   '아티스트': '지아 (Zia)',
#   '앨범명': '사랑하기 싫어',
#   '순위': 61},
#  {'날짜': '20230609',
#   '곡명': '2002',
#   '아티스트': 'Anne-Marie',
#   '앨범명': 'Speak Your Mind (Deluxe)',
#   '순위': 62},
#  {'날짜': '20230609', '곡명': '모래 알갱이', '아티스트': '임영웅', '앨범명': '모래 알갱이', '순위': 63},
#  {'날짜': '20230609', '곡명': '신호등', '아티스트': '이무진', '앨범명': '신호등', '순위': 64},
#  {'날짜': '20230609',
#   '곡명': 'FEARLESS',
#   '아티스트': 'LE SSERAFIM (르세라핌)',
#   '앨범명': 'FEARLESS',
#   '순위': 65},
#  {'날짜': '20230609',
#   '곡명': '주저하는 연인들을 위해',
#   '아티스트': '잔나비',
#   '앨범명': '전설',
#   '순위': 66},
#  {'날짜': '20230609',
#   '곡명': '이제 나만 믿어요',
#   '아티스트': '임영웅',
#   '앨범명': '내일은 미스터트롯 우승자 특전곡',
#   '순위': 67},
#  {'날짜': '20230609',
#   '곡명': '보고싶었어',
#   '아티스트': 'WSG워너비 (4FIRE)',
#   '앨범명': 'WSG워너비 1집',
#   '순위': 68},
#  {'날짜': '20230609',
#   '곡명': '정이라고 하자 (Feat. 10CM)',
#   '아티스트': 'BIG Naughty (서동현)',
#   '앨범명': '정이라고 하자',
#   '순위': 69},
#  {'날짜': '20230609',
#   '곡명': '나의 바람 (Wind And Wish)',
#   '아티스트': '비투비',
#   '앨범명': 'WIND AND WISH',
#   '순위': 70},
#  {'날짜': '20230609',
#   '곡명': '다시 만날 수 있을까',
#   '아티스트': '임영웅',
#   '앨범명': 'IM HERO',
#   '순위': 71},
#  {'날짜': '20230609',
#   '곡명': '모든 날, 모든 순간 (Every day, Every Moment)',
#   '아티스트': '폴킴',
#   '앨범명': "'키스 먼저 할까요?' OST Part. 3 (SBS 월화드라마)",
#   '순위': 72},
#  {'날짜': '20230609',
#   '곡명': 'Cookie',
#   '아티스트': 'NewJeans',
#   '앨범명': "NewJeans 1st EP 'New Jeans'",
#   '순위': 73},
#  {'날짜': '20230609',
#   '곡명': '찬란한 하루',
#   '아티스트': '멜로망스 (MeloMance)',
#   '앨범명': '찬란한 하루',
#   '순위': 74},
#  {'날짜': '20230609',
#   '곡명': 'Thirsty',
#   '아티스트': 'aespa',
#   '앨범명': 'MY WORLD - The 3rd Mini Album',
#   '순위': 75},
#  {'날짜': '20230609',
#   '곡명': '같이 살자',
#   '아티스트': 'DK (디셈버)',
#   '앨범명': '같이 살자',
#   '순위': 76},
#  {'날짜': '20230609',
#   '곡명': 'Dreamers (Music from the FIFA World Cup Qatar 2022 Official Soundtrack) (Feat. FIFA Sound)',
#   '아티스트': '정국 & 방탄소년단',
#   '앨범명': 'Dreamers (Music from the FIFA World Cup Qatar 2022 Official Soundtrack)',
#   '순위': 77},
#  {'날짜': '20230609',
#   '곡명': 'VIBE (Feat. Jimin of BTS)',
#   '아티스트': '태양',
#   '앨범명': 'VIBE',
#   '순위': 78},
#  {'날짜': '20230609', '곡명': '희재', '아티스트': '성시경', '앨범명': '국화꽃 향기 OST', '순위': 79},
#  {'날짜': '20230609',
#   '곡명': 'Off My Face',
#   '아티스트': 'Justin Bieber',
#   '앨범명': 'Justice',
#   '순위': 80},
#  {'날짜': '20230609',
#   '곡명': '흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야',
#   '아티스트': '장범준',
#   '앨범명': '멜로가 체질 OST Part 3 (JTBC 금토 드라마)',
#   '순위': 81},
#  {'날짜': '20230609',
#   '곡명': '밤하늘의 별을 (2020)',
#   '아티스트': '경서',
#   '앨범명': '밤하늘의 별을 (2020)',
#   '순위': 82},
#  {'날짜': '20230609',
#   '곡명': 'NOT SORRY (Feat. pH-1) (Prod. by Slom)',
#   '아티스트': '이영지',
#   '앨범명': '쇼미더머니 11 Episode 3',
#   '순위': 83},
#  {'날짜': '20230609',
#   '곡명': 'INVU',
#   '아티스트': '태연 (TAEYEON)',
#   '앨범명': 'INVU - The 3rd Album',
#   '순위': 84},
#  {'날짜': '20230609',
#   '곡명': '봄여름가을겨울 (Still Life)',
#   '아티스트': 'BIGBANG (빅뱅)',
#   '앨범명': '봄여름가을겨울 (Still Life)',
#   '순위': 85},
#  {'날짜': '20230609',
#   '곡명': 'Every Second',
#   '아티스트': 'Mina Okabe',
#   '앨범명': 'Every Second',
#   '순위': 86},
#  {'날짜': '20230609',
#   '곡명': 'Unholy',
#   '아티스트': 'Sam Smith & Kim Petras',
#   '앨범명': 'Unholy',
#   '순위': 87},
#  {'날짜': '20230609',
#   '곡명': 'Butter',
#   '아티스트': '방탄소년단',
#   '앨범명': 'Butter',
#   '순위': 88},
#  {'날짜': '20230609',
#   '곡명': '첫 키스에 내 심장은 120BPM',
#   '아티스트': '경서',
#   '앨범명': 'ONGOING',
#   '순위': 89},
#  {'날짜': '20230609',
#   '곡명': 'Say I Love You',
#   '아티스트': '우디 (Woody)',
#   '앨범명': 'Say I Love You (Re : WIND 4MEN Vol.04)',
#   '순위': 90},
#  {'날짜': '20230609',
#   '곡명': 'Weekend',
#   '아티스트': '태연 (TAEYEON)',
#   '앨범명': 'Weekend',
#   '순위': 91},
#  {'날짜': '20230609',
#   '곡명': '혼자라고 생각말기',
#   '아티스트': '임한별',
#   '앨범명': '혼자라고 생각말기',
#   '순위': 92},
#  {'날짜': '20230609', '곡명': '처음처럼', '아티스트': '송하예', '앨범명': '처음처럼', '순위': 93},
#  {'날짜': '20230609',
#   '곡명': '사랑은 가슴이 시킨다 (2023)',
#   '아티스트': '이창섭',
#   '앨범명': '시작은 첫키스 OST Part.7',
#   '순위': 94},
#  {'날짜': '20230609',
#   '곡명': 'Bad Habits',
#   '아티스트': 'Ed Sheeran',
#   '앨범명': '=',
#   '순위': 95},
#  {'날짜': '20230609',
#   '곡명': 'London Boy',
#   '아티스트': '임영웅',
#   '앨범명': 'Polaroid',
#   '순위': 96},
#  {'날짜': '20230609', '곡명': '무지개', '아티스트': '임영웅', '앨범명': 'IM HERO', '순위': 97},
#  {'날짜': '20230609',
#   '곡명': 'LOVE me',
#   '아티스트': "BE'O (비오)",
#   '앨범명': 'LOVE me',
#   '순위': 98},
#  {'날짜': '20230609',
#   '곡명': '딱 10CM만',
#   '아티스트': '10CM & BIG Naughty (서동현)',
#   '앨범명': '딱 10CM만',
#   '순위': 99},
#  {'날짜': '20230609',
#   '곡명': '우리 왜 헤어져야 해 (여름날 우리 X 전상근)',
#   '아티스트': '전상근',
#   '앨범명': '우리 왜 헤어져야 해 (여름날 우리 X 전상근)',
#   '순위': 100},
#  {'날짜': '20230610',
#   '곡명': '퀸카 (Queencard)',
#   '아티스트': '(여자)아이들',
#   '앨범명': 'I feel',
#   '순위': 1},
#  {'날짜': '20230610',
#   '곡명': 'I AM',
#   '아티스트': 'IVE (아이브)',
#   '앨범명': "I've IVE",
#   '순위': 2},
#  {'날짜': '20230610',
#   '곡명': 'Spicy',
#   '아티스트': 'aespa',
#   '앨범명': 'MY WORLD - The 3rd Mini Album',
#   '순위': 3},
#  {'날짜': '20230610',
#   '곡명': 'Kitsch',
#   '아티스트': 'IVE (아이브)',
#   '앨범명': "I've IVE",
#   '순위': 4},
#  {'날짜': '20230610',
#   '곡명': 'UNFORGIVEN (Feat. Nile Rodgers)',
#   '아티스트': 'LE SSERAFIM (르세라핌)',
#   '앨범명': 'UNFORGIVEN',
#   '순위': 5},
#  {'날짜': '20230610', '곡명': '꽃', '아티스트': '지수 (JISOO)', '앨범명': 'ME', '순위': 6},
#  {'날짜': '20230610',
#   '곡명': 'Hype boy',
#   '아티스트': 'NewJeans',
#   '앨범명': "NewJeans 1st EP 'New Jeans'",
#   '순위': 7},
#  {'날짜': '20230610',
#   '곡명': '이브, 프시케 그리고 푸른 수염의 아내',
#   '아티스트': 'LE SSERAFIM (르세라핌)',
#   '앨범명': 'UNFORGIVEN',
#   '순위': 8},
#  {'날짜': '20230610',
#   '곡명': 'Ditto',
#   '아티스트': 'NewJeans',
#   '앨범명': "NewJeans 'OMG'",
#   '순위': 9},
#  {'날짜': '20230610',
#   '곡명': '사건의 지평선',
#   '아티스트': '윤하 (YOUNHA)',
#   '앨범명': "YOUNHA 6th Album Repackage 'END THEORY : Final Edition'",
#   '순위': 10},
#  {'날짜': '20230610',
#   '곡명': 'Cupid',
#   '아티스트': 'FIFTY FIFTY',
#   '앨범명': 'The Beginning : Cupid',
#   '순위': 11},
#  {'날짜': '20230610',
#   '곡명': "I Don't Think That I Like Her",
#   '아티스트': 'Charlie Puth',
#   '앨범명': 'CHARLIE',
#   '순위': 12},
#  {'날짜': '20230610',
#   '곡명': 'After LIKE',
#   '아티스트': 'IVE (아이브)',
#   '앨범명': 'After LIKE',
#   '순위': 13},
#  {'날짜': '20230610',
#   '곡명': '손오공',
#   '아티스트': '세븐틴 (SEVENTEEN)',
#   '앨범명': "SEVENTEEN 10th Mini Album 'FML'",
#   '순위': 14},
#  {'날짜': '20230610',
#   '곡명': '심 (心)',
#   '아티스트': 'DK (디셈버)',
#   '앨범명': '심 (心)',
#   '순위': 15},
#  {'날짜': '20230610',
#   '곡명': 'Teddy Bear',
#   '아티스트': 'STAYC (스테이씨)',
#   '앨범명': 'Teddy Bear',
#   '순위': 16},
#  {'날짜': '20230610',
#   '곡명': 'OMG',
#   '아티스트': 'NewJeans',
#   '앨범명': "NewJeans 'OMG'",
#   '순위': 17},
#  {'날짜': '20230610',
#   '곡명': 'LOVE DIVE',
#   '아티스트': 'IVE (아이브)',
#   '앨범명': 'LOVE DIVE',
#   '순위': 18},
#  {'날짜': '20230610',
#   '곡명': 'Dangerously',
#   '아티스트': 'Charlie Puth',
#   '앨범명': 'Nine Track Mind (Deluxe Edition)',
#   '순위': 19},
#  {'날짜': '20230610',
#   '곡명': '파이팅 해야지 (Feat. 이영지)',
#   '아티스트': '부석순 (SEVENTEEN)',
#   '앨범명': "부석순 1st Single Album 'SECOND WIND'",
#   '순위': 20},
#  {'날짜': '20230610',
#   '곡명': 'Attention',
#   '아티스트': 'NewJeans',
#   '앨범명': "NewJeans 1st EP 'New Jeans'",
#   '순위': 21},
#  {'날짜': '20230610',
#   '곡명': '헤어지자 말해요',
#   '아티스트': '박재정',
#   '앨범명': '1집 Alone',
#   '순위': 22},
#  {'날짜': '20230610',
#   '곡명': 'ANTIFRAGILE',
#   '아티스트': 'LE SSERAFIM (르세라핌)',
#   '앨범명': 'ANTIFRAGILE',
#   '순위': 23},
#  {'날짜': '20230610',
#   '곡명': 'CHRISTIAN',
#   '아티스트': 'Zior Park',
#   '앨범명': 'WHERE DOES SASQUATCH LIVE? PART 1',
#   '순위': 24},
#  {'날짜': '20230610',
#   '곡명': '사랑인가 봐',
#   '아티스트': '멜로망스 (MeloMance)',
#   '앨범명': '사랑인가 봐 (사내맞선 OST 스페셜 트랙)',
#   '순위': 25},
#  {'날짜': '20230610',
#   '곡명': '건물 사이에 피어난 장미',
#   '아티스트': 'H1-KEY (하이키)',
#   '앨범명': 'H1-KEY 1st Mini Album (Rose Blossom)',
#   '순위': 26},
#  {'날짜': '20230610',
#   '곡명': '사랑은 늘 도망가',
#   '아티스트': '임영웅',
#   '앨범명': '신사와 아가씨 OST Part.2',
#   '순위': 27},
#  {'날짜': '20230610',
#   '곡명': 'NIGHT DANCER',
#   '아티스트': 'imase',
#   '앨범명': 'NIGHT DANCER',
#   '순위': 28},
#  {'날짜': '20230610', '곡명': '물론', '아티스트': '허각', '앨범명': '물론', '순위': 29},
#  {'날짜': '20230610',
#   '곡명': 'TOMBOY',
#   '아티스트': '(여자)아이들',
#   '앨범명': 'I NEVER DIE',
#   '순위': 30},
#  {'날짜': '20230610',
#   '곡명': "That's Hilarious",
#   '아티스트': 'Charlie Puth',
#   '앨범명': 'CHARLIE',
#   '순위': 31},
#  {'날짜': '20230610',
#   '곡명': '사실말야내가말야그게그러니까말이야',
#   '아티스트': '케이시 (Kassy)',
#   '앨범명': '사실말야내가말야그게그러니까말이야',
#   '순위': 32},
#  {'날짜': '20230610',
#   '곡명': 'The Drum',
#   '아티스트': 'Alan Walker',
#   '앨범명': 'Walkerverse, Pt. I',
#   '순위': 33},
#  {'날짜': '20230610',
#   '곡명': 'Nxde',
#   '아티스트': '(여자)아이들',
#   '앨범명': 'I love',
#   '순위': 34},
#  {'날짜': '20230610',
#   '곡명': '다정히 내 이름을 부르면',
#   '아티스트': '경서예지 & 전건호',
#   '앨범명': '다정히 내 이름을 부르면',
#   '순위': 35},
#  {'날짜': '20230610',
#   '곡명': '취중고백',
#   '아티스트': '김민석 (멜로망스)',
#   '앨범명': '취중고백',
#   '순위': 36},
#  {'날짜': '20230610',
#   '곡명': '너의 모든 순간',
#   '아티스트': '성시경',
#   '앨범명': '별에서 온 그대 OST Part.7 (SBS 수목드라마)',
#   '순위': 37},
#  {'날짜': '20230610',
#   '곡명': 'KNOCK',
#   '아티스트': '이채연',
#   '앨범명': 'Over The Moon',
#   '순위': 38},
#  {'날짜': '20230610',
#   '곡명': 'Heaven (2023)',
#   '아티스트': '임재현',
#   '앨범명': '시작은 첫키스 OST Part.1',
#   '순위': 39},
#  {'날짜': '20230610',
#   '곡명': '그때 그 순간 그대로 (그그그)',
#   '아티스트': 'WSG워너비 (가야G)',
#   '앨범명': 'WSG워너비 1집',
#   '순위': 40},
#  {'날짜': '20230610',
#   '곡명': 'Stay',
#   '아티스트': 'The Kid LAROI & Justin Bieber',
#   '앨범명': 'Stay',
#   '순위': 41},
#  {'날짜': '20230610',
#   '곡명': 'When I Get Old',
#   '아티스트': 'Christopher & 청하',
#   '앨범명': 'When I Get Old',
#   '순위': 42},
#  {'날짜': '20230610',
#   '곡명': '빛이 나는 너에게',
#   '아티스트': '던 (DAWN)',
#   '앨범명': '빛이 나는 너에게',
#   '순위': 43},
#  {'날짜': '20230610',
#   '곡명': 'Shut Down',
#   '아티스트': 'BLACKPINK',
#   '앨범명': 'BORN PINK',
#   '순위': 44},
#  {'날짜': '20230610',
#   '곡명': '새삥 (Prod. by ZICO) (Feat. 호미들)',
#   '아티스트': '지코 (ZICO)',
#   '앨범명': '스트릿 맨 파이터(SMF) Original Vol.3 (계급미션)',
#   '순위': 45},
#  {'날짜': '20230610',
#   '곡명': 'Monologue',
#   '아티스트': '테이 (Tei)',
#   '앨범명': 'Monologue',
#   '순위': 46},
#  {'날짜': '20230610', '곡명': '그라데이션', '아티스트': '10CM', '앨범명': '5.3', '순위': 47},
#  {'날짜': '20230610',
#   '곡명': '우리들의 블루스',
#   '아티스트': '임영웅',
#   '앨범명': 'IM HERO',
#   '순위': 48},
#  {'날짜': '20230610', '곡명': '나의 X에게', '아티스트': '경서', '앨범명': '나의 X에게', '순위': 49},
#  {'날짜': '20230610',
#   '곡명': 'Allergy',
#   '아티스트': '(여자)아이들',
#   '앨범명': 'I feel',
#   '순위': 50},
#  {'날짜': '20230610',
#   '곡명': '해요 (2022)',
#   '아티스트': '#안녕',
#   '앨범명': '해요 (2022)',
#   '순위': 51},
#  {'날짜': '20230610',
#   '곡명': 'ELEVEN',
#   '아티스트': 'IVE (아이브)',
#   '앨범명': 'ELEVEN',
#   '순위': 52},
#  {'날짜': '20230610',
#   '곡명': 'Pink Venom',
#   '아티스트': 'BLACKPINK',
#   '앨범명': 'BORN PINK',
#   '순위': 53},
#  {'날짜': '20230610',
#   '곡명': 'Dynamite',
#   '아티스트': '방탄소년단',
#   '앨범명': 'Dynamite (DayTime Ver.)',
#   '순위': 54},
#  {'날짜': '20230610',
#   '곡명': '오르트구름',
#   '아티스트': '윤하 (YOUNHA)',
#   '앨범명': "YOUNHA 6th Album 'END THEORY'",
#   '순위': 55},
#  {'날짜': '20230610',
#   '곡명': '주저하는 연인들을 위해',
#   '아티스트': '잔나비',
#   '앨범명': '전설',
#   '순위': 56},
#  {'날짜': '20230610', '곡명': '모래 알갱이', '아티스트': '임영웅', '앨범명': '모래 알갱이', '순위': 57},
#  {'날짜': '20230610',
#   '곡명': '사랑..그게 뭔데',
#   '아티스트': '지아 (Zia)',
#   '앨범명': '사랑..그게 뭔데',
#   '순위': 58},
#  {'날짜': '20230610', '곡명': '내가 아니라도', '아티스트': '주호', '앨범명': '내가 아니라도', '순위': 59},
#  {'날짜': '20230610',
#   '곡명': 'Loving You Girl (Feat. Hkeem)',
#   '아티스트': 'Peder Elias',
#   '앨범명': 'Love & Loneliness',
#   '순위': 60},
#  {'날짜': '20230610',
#   '곡명': '잠깐 시간 될까',
#   '아티스트': '이무진',
#   '앨범명': '잠깐 시간 될까',
#   '순위': 61},
#  {'날짜': '20230610',
#   '곡명': '사랑하기 싫어',
#   '아티스트': '지아 (Zia)',
#   '앨범명': '사랑하기 싫어',
#   '순위': 62},
#  {'날짜': '20230610',
#   '곡명': '이제 나만 믿어요',
#   '아티스트': '임영웅',
#   '앨범명': '내일은 미스터트롯 우승자 특전곡',
#   '순위': 63},
#  {'날짜': '20230610',
#   '곡명': '2002',
#   '아티스트': 'Anne-Marie',
#   '앨범명': 'Speak Your Mind (Deluxe)',
#   '순위': 64},
#  {'날짜': '20230610', '곡명': '신호등', '아티스트': '이무진', '앨범명': '신호등', '순위': 65},
#  {'날짜': '20230610',
#   '곡명': 'FEARLESS',
#   '아티스트': 'LE SSERAFIM (르세라핌)',
#   '앨범명': 'FEARLESS',
#   '순위': 66},
#  {'날짜': '20230610',
#   '곡명': '다시 만날 수 있을까',
#   '아티스트': '임영웅',
#   '앨범명': 'IM HERO',
#   '순위': 67},
#  {'날짜': '20230610',
#   '곡명': '정이라고 하자 (Feat. 10CM)',
#   '아티스트': 'BIG Naughty (서동현)',
#   '앨범명': '정이라고 하자',
#   '순위': 68},
#  {'날짜': '20230610',
#   '곡명': 'Dreamers (Music from the FIFA World Cup Qatar 2022 Official Soundtrack) (Feat. FIFA Sound)',
#   '아티스트': '정국 & 방탄소년단',
#   '앨범명': 'Dreamers (Music from the FIFA World Cup Qatar 2022 Official Soundtrack)',
#   '순위': 69},
#  {'날짜': '20230610',
#   '곡명': '모든 날, 모든 순간 (Every day, Every Moment)',
#   '아티스트': '폴킴',
#   '앨범명': "'키스 먼저 할까요?' OST Part. 3 (SBS 월화드라마)",
#   '순위': 70},
#  {'날짜': '20230610',
#   '곡명': '보고싶었어',
#   '아티스트': 'WSG워너비 (4FIRE)',
#   '앨범명': 'WSG워너비 1집',
#   '순위': 71},
#  {'날짜': '20230610',
#   '곡명': 'Cookie',
#   '아티스트': 'NewJeans',
#   '앨범명': "NewJeans 1st EP 'New Jeans'",
#   '순위': 72},
#  {'날짜': '20230610',
#   '곡명': '나의 바람 (Wind And Wish)',
#   '아티스트': '비투비',
#   '앨범명': 'WIND AND WISH',
#   '순위': 73},
#  {'날짜': '20230610', '곡명': '희재', '아티스트': '성시경', '앨범명': '국화꽃 향기 OST', '순위': 74},
#  {'날짜': '20230610',
#   '곡명': 'Thirsty',
#   '아티스트': 'aespa',
#   '앨범명': 'MY WORLD - The 3rd Mini Album',
#   '순위': 75},
#  {'날짜': '20230610',
#   '곡명': 'Off My Face',
#   '아티스트': 'Justin Bieber',
#   '앨범명': 'Justice',
#   '순위': 76},
#  {'날짜': '20230610',
#   '곡명': 'VIBE (Feat. Jimin of BTS)',
#   '아티스트': '태양',
#   '앨범명': 'VIBE',
#   '순위': 77},
#  {'날짜': '20230610',
#   '곡명': '밤하늘의 별을 (2020)',
#   '아티스트': '경서',
#   '앨범명': '밤하늘의 별을 (2020)',
#   '순위': 78},
#  {'날짜': '20230610',
#   '곡명': '찬란한 하루',
#   '아티스트': '멜로망스 (MeloMance)',
#   '앨범명': '찬란한 하루',
#   '순위': 79},
#  {'날짜': '20230610',
#   '곡명': 'Say I Love You',
#   '아티스트': '우디 (Woody)',
#   '앨범명': 'Say I Love You (Re : WIND 4MEN Vol.04)',
#   '순위': 80},
#  {'날짜': '20230610',
#   '곡명': 'Every Second',
#   '아티스트': 'Mina Okabe',
#   '앨범명': 'Every Second',
#   '순위': 81},
#  {'날짜': '20230610',
#   '곡명': '특',
#   '아티스트': 'Stray Kids (스트레이 키즈)',
#   '앨범명': '★★★★★ (5-STAR)',
#   '순위': 82},
#  {'날짜': '20230610',
#   '곡명': 'NOT SORRY (Feat. pH-1) (Prod. by Slom)',
#   '아티스트': '이영지',
#   '앨범명': '쇼미더머니 11 Episode 3',
#   '순위': 83},
#  {'날짜': '20230610',
#   '곡명': '첫 키스에 내 심장은 120BPM',
#   '아티스트': '경서',
#   '앨범명': 'ONGOING',
#   '순위': 84},
#  {'날짜': '20230610',
#   '곡명': 'Unholy',
#   '아티스트': 'Sam Smith & Kim Petras',
#   '앨범명': 'Unholy',
#   '순위': 85},
#  {'날짜': '20230610',
#   '곡명': 'INVU',
#   '아티스트': '태연 (TAEYEON)',
#   '앨범명': 'INVU - The 3rd Album',
#   '순위': 86},
#  {'날짜': '20230610',
#   '곡명': '봄여름가을겨울 (Still Life)',
#   '아티스트': 'BIGBANG (빅뱅)',
#   '앨범명': '봄여름가을겨울 (Still Life)',
#   '순위': 87},
#  {'날짜': '20230610',
#   '곡명': 'Butter',
#   '아티스트': '방탄소년단',
#   '앨범명': 'Butter',
#   '순위': 88},
#  {'날짜': '20230610',
#   '곡명': '사랑의 바보',
#   '아티스트': '제이세라 (J-Cera)',
#   '앨범명': '사랑의 바보',
#   '순위': 89},
#  {'날짜': '20230610',
#   '곡명': '흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야',
#   '아티스트': '장범준',
#   '앨범명': '멜로가 체질 OST Part 3 (JTBC 금토 드라마)',
#   '순위': 90},
#  {'날짜': '20230610', '곡명': '무지개', '아티스트': '임영웅', '앨범명': 'IM HERO', '순위': 91},
#  {'날짜': '20230610',
#   '곡명': 'London Boy',
#   '아티스트': '임영웅',
#   '앨범명': 'Polaroid',
#   '순위': 92},
#  {'날짜': '20230610',
#   '곡명': '사랑은 가슴이 시킨다 (2023)',
#   '아티스트': '이창섭',
#   '앨범명': '시작은 첫키스 OST Part.7',
#   '순위': 93},
#  {'날짜': '20230610',
#   '곡명': 'Bad Habits',
#   '아티스트': 'Ed Sheeran',
#   '앨범명': '=',
#   '순위': 94},
#  {'날짜': '20230610',
#   '곡명': 'Take Two',
#   '아티스트': '방탄소년단',
#   '앨범명': 'Take Two',
#   '순위': 95},
#  {'날짜': '20230610',
#   '곡명': 'LOVE me',
#   '아티스트': "BE'O (비오)",
#   '앨범명': 'LOVE me',
#   '순위': 96},
#  {'날짜': '20230610',
#   '곡명': '딱 10CM만',
#   '아티스트': '10CM & BIG Naughty (서동현)',
#   '앨범명': '딱 10CM만',
#   '순위': 97},
#  {'날짜': '20230610',
#   '곡명': 'Blueming',
#   '아티스트': '아이유 (IU)',
#   '앨범명': 'Love poem',
#   '순위': 98},
#  {'날짜': '20230610',
#   '곡명': 'Candy',
#   '아티스트': 'NCT DREAM',
#   '앨범명': 'Candy - Winter Special Mini Album',
#   '순위': 99},
#  {'날짜': '20230610',
#   '곡명': '봄날',
#   '아티스트': '방탄소년단',
#   '앨범명': 'YOU NEVER WALK ALONE',
#   '순위': 100},
#  ...]

# %% [markdown]
# DataFrame 사용

# %%
df = DataFrame(genie_chart)

# 순위를 우선해서 보여주기 위해 index로 설정
df.set_index('순위',inplace=True)
# df
df.to_excel("genie_chart.xlsx")
